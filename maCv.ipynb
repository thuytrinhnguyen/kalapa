# %%
import pandas as pd
from utils import check_nas, unique_values, values_only_in_set

# %% [markdown]
# ### 1. Load dataset

# %%
train = pd.read_csv('data/train.csv', index_col=0, low_memory=False)
test = pd.read_csv('data/test.csv', index_col=0, low_memory=False)

# %% [markdown]
# ### 2. Check for NAs

# %% [markdown]
# Check no. missing values for Train

# %%
check_nas(train,'maCv')
# Out:
# (9679, 0.3226333333333333)

# %% [markdown]
# Check no. missing value for Test

# %%
check_nas(test,'maCv')
# Out:
# (6504, 0.2168)

# %% [markdown]
# ### 3. Check for Unique Values

# %% [markdown]
# #### Similar Unique values in Train & Test

# %%
set(train.maCv.unique()).intersection(set(test.maCv.unique()))
# Out:
# {'Bác sĩ',
#  'Bác sỹ',
#  'Bán hàng',
#  'Bí thư đoàn thanh niên',
#  'Bảo Vệ',
#  'Bảo vệ',
#  'Bếp chính',
#  'Bốc xếp',
#  'C.n',
#  'C.nhân kiểm hàng',
#  'C.nhân may',
#  'CN',
#  'CN KT Mủ',
#  'CN Kỹ thuật',
#  'CN MAY',
#  'CN May',
#  'CN May công nghiệp',
#  'CN Sản xuất',
#  'CN SắT',
#  'CN Thủ Công',
#  'CN kiểm hàng',
#  'CN may',
#  'CN may CN',
#  'CN may công nghiệp',
#  'CN may trực tiếp CN',
#  'CN mộc máy',
#  'CN sửa chữa cơ điện trong hầm lò',
#  'CN vận hành máy may',
#  'CN vận hành máy may CN',
#  'CN vận hành máy may công nghiệp',
#  'CNV',
#  'Cao đẳng điều dưỡng',
#  'Chuyên viên',
#  'Chăm sóc',
#  'Chỉ huy trưởng quân sự',
#  'Cn Kiểm Tra Chất Lượng',
#  'Coõng nhaõn boọ phaọn Nos E',
#  'Coõng nhaõn trửùc tieỏp maựy may coõng nghieọp',
#  'CÔNG NHÂN',
#  'CÔNG NHÂN LẮP RÁP',
#  'CÔNG NHÂN MAY',
#  'CÔNG NHÂN MAY CÔNG NGHIệP',
#  'CÔNG NHÂN PHụ MAY CÔNG NGHIệP',
#  'CÔNG NHÂN SảN XUấT ĐIệN Tử',
#  'Cán bộ',
#  'Cán bộ cấp 2',
#  'Cán bộ không chuyên trách',
#  'Cán bộ kỹ thuật',
#  'Cán bộ nhân viên',
#  'Cán bộ tín dụng',
#  'Cán bộ tư pháp',
#  'Cán sự',
#  'Công Nhân',
#  'Công Nhân Chuyền May',
#  'Công Nhân Chuyền Thành Hình',
#  'Công Nhân Chà Nhám',
#  'Công Nhân Dệt',
#  'Công Nhân Hoàn Chỉnh',
#  'Công Nhân Kho',
#  'Công Nhân Kiểm Hàng',
#  'Công Nhân Lắp Ráp',
#  'Công Nhân May',
#  'Công Nhân May Công Nghiệp',
#  'Công Nhân May Vi Tính',
#  'Công Nhân SX Điện tử',
#  'Công Nhân Sản Xuất',
#  'Công Nhân Sản xuất',
#  'Công Nhân Thành Hình',
#  'Công Nhân Viên',
#  'Công Nhân Vận Hành Máy May',
#  'Công Nhân may',
#  'Công Nhân may công nghiệp',
#  'Công Nhân sản xuất',
#  'Công Nhân Đóng Gói',
#  'Công Nhân Đứng Máy',
#  'Công Nhân ủi',
#  'Công Nhân-Chuyền Thành Hình',
#  'Công nhân',
#  'Công nhân  May',
#  'Công nhân  may',
#  'Công nhân (sản xuất nền đĩa thủy tinh) .Phòng Sản xuất',
#  'Công nhân Chế biến',
#  'Công nhân Cán  luyện cao su trong sản xuất giầy dép',
#  'Công nhân Cạo mủ',
#  'Công nhân Cắt',
#  'Công nhân Dán',
#  'Công nhân Dập',
#  'Công nhân Gia Công Ván A',
#  'Công nhân Hoàn Thành',
#  'Công nhân Hàn',
#  'Công nhân In lụa',
#  'Công nhân KCS',
#  'Công nhân Kiểm tra chất lượng',
#  'Công nhân Là',
#  'Công nhân May',
#  'Công nhân May công nghiệp',
#  'Công nhân Nobashi',
#  'Công nhân QC',
#  'Công nhân SX',
#  'Công nhân Sơn',
#  'Công nhân Sơn B',
#  'Công nhân Sản Xuất',
#  'Công nhân Sản xuất',
#  'Công nhân Sản xuất lắp ráp',
#  'Công nhân Sản xuất lắp ráp Máy giặt',
#  'Công nhân Sửa cá',
#  'Công nhân T12MAY3',
#  'Công nhân Thành Hình',
#  'Công nhân Thành hình',
#  'Công nhân Thủ công',
#  'Công nhân Vận hành máy may',
#  'Công nhân bao bì',
#  'Công nhân bán lẻ xăng dầu',
#  'Công nhân bê tông',
#  'Công nhân bốc xếp',
#  'Công nhân bốc xếp thủ công',
#  'Công nhân bộ phận Gia công',
#  'Công nhân bộ phận QA',
#  'Công nhân bộ phận đế Outsole',
#  'Công nhân chuẩn bị',
#  'Công nhân chà nhám',
#  'Công nhân chăm sóc cà phê',
#  'Công nhân chăn nuôi  chăm sóc  vệ sinh chuồng trại gia súc  gia cầm',
#  'Công nhân chế biến hải sản',
#  'Công nhân chế biến mủ cao su',
#  'Công nhân chế biến thủy hải sản đông lạnh',
#  'Công nhân chế biến thủy sản',
#  'Công nhân cơ khí',
#  'Công nhân cạo mủ',
#  'Công nhân cạo mủ cao su',
#  'Công nhân cắt',
#  'Công nhân cắt phá  cắt gọt',
#  'Công nhân cắt vải may công nghiệp',
#  'Công nhân dệt',
#  'Công nhân dệt dây giày',
#  'Công nhân gia công',
#  'Công nhân gia công đế',
#  'Công nhân giao nhận',
#  'Công nhân hoàn chỉnh',
#  'Công nhân hoàn thiện',
#  'Công nhân hoàn thành',
#  'Công nhân hàn',
#  'Công nhân hình thành',
#  'Công nhân in',
#  'Công nhân in lụa',
#  'Công nhân khai thác khoáng sản trong hầm lò',
#  'Công nhân khai thác mỏ hầm lò',
#  'Công nhân khai thác mủ cao su',
#  'Công nhân khai thác than trong hầm lò',
#  'Công nhân kho',
#  'Công nhân kho vật tư',
#  'Công nhân khuôn',
#  'Công nhân khuôn đúc',
#  'Công nhân kiểm hàng',
#  'Công nhân kiểm hóa',
#  'Công nhân kiểm tra',
#  'Công nhân kiểm tra chất lượng',
#  'Công nhân kiểm tra chất lượng sản phẩm',
#  'Công nhân kỹ thuật',
#  'Công nhân lao động phổ thông',
#  'Công nhân là',
#  'Công nhân lái xe',
#  'Công nhân lắp ráp',
#  'Công nhân lắp ráp linh kiện điện tử',
#  'Công nhân lắp ráp mạch điện tử',
#  'Công nhân may',
#  'Công nhân may CN',
#  'Công nhân may công nghiệp',
#  'Công nhân may giày',
#  'Công nhân may máy may công nghiệp',
#  'Công nhân may tay',
#  'Công nhân máy ép',
#  'Công nhân mạ đồng',
#  'Công nhân mộc',
#  'Công nhân nhuộm',
#  'Công nhân pha keo',
#  'Công nhân phòng Sản xuất',
#  'Công nhân phòng chế tạo',
#  'Công nhân phòng máy',
#  'Công nhân phòng sản xuất Ato',
#  'Công nhân phổ thông',
#  'Công nhân phụ',
#  'Công nhân phụ may',
#  'Công nhân phụ may công nghiệp',
#  'Công nhân phụ việc',
#  'Công nhân quét keo dán chi tiết',
#  'Công nhân sản xuất',
#  'Công nhân sản xuất Camera',
#  'Công nhân sản xuất camera điện thoại',
#  'Công nhân sản xuất dây dẫn điện',
#  'Công nhân sản xuất linh kiện Camera',
#  'Công nhân sản xuất linh kiện điện tử',
#  'Công nhân sản xuất nền đĩa thủy tinh',
#  'Công nhân sản xuất roong',
#  'Công nhân sản xuất sơn',
#  'Công nhân sản xuất thiết bị điện tử',
#  'Công nhân sản xuất túi khí vô lăng ô tô',
#  'Công nhân sản xuất điện tử',
#  'Công nhân sửa chữa',
#  'Công nhân sửa cá',
#  'Công nhân thao tác công đoạn chuẩn bị',
#  'Công nhân thành hình',
#  'Công nhân thủ công',
#  'Công nhân thủ công may',
#  'Công nhân trại heo',
#  'Công nhân trải vải',
#  'Công nhân trồng chè',
#  'Công nhân trồng và thu hoạch',
#  'Công nhân tổ May mũ giày',
#  'Công nhân tổ cắt',
#  'Công nhân viên',
#  'Công nhân vận hành',
#  'Công nhân vận hành dây chuyền sợi',
#  'Công nhân vận hành máy may',
#  'Công nhân vận hành máy may (may công nghiệp)',
#  'Công nhân vận hành máy may CN',
#  'Công nhân vận hành máy may công nghiệp',
#  'Công nhân vận hành máy sản xuất van',
#  'Công nhân vận hành thiết bị',
#  'Công nhân vận hành thiết bị may công nghiệp',
#  'Công nhân vận hành thiết bị may công nghiệp  bậc 1/6',
#  'Công nhân vệ sinh',
#  'Công nhân vệ sinh môi trường',
#  'Công nhân ép',
#  'Công nhân ép cao tầng',
#  'Công nhân ép nhựa',
#  'Công nhân ép đế',
#  'Công nhân Đánh số',
#  'Công nhân Đóng gói',
#  'Công nhân Đế',
#  'Công nhân Định hình',
#  'Công nhân điện',
#  'Công nhân điện tử',
#  'Công nhân đào tạo',
#  'Công nhân đánh số',
#  'Công nhân đóng gói',
#  'Công nhân đóng kiện',
#  'Công nhân đóng thùng',
#  'Công nhân đội vệ sinh',
#  'Công nhân đứng máy',
#  'Công nhân ủi',
#  'Công nhân ủi may công nghiệp',
#  'Công nhân-in hóa chất',
#  'Công nhân-ép tem đệm lót',
#  'Cấp dưỡng',
#  'Dược Sỹ Bán Hàng',
#  'Dược sĩ',
#  'Dược sỹ',
#  'GIÁO VIÊN',
#  'GV',
#  'Gia Công Đế',
#  'Giao Hàng',
#  'Giao dịch viên',
#  'Giao dịch viên cửa hàng',
#  'Giao nhận',
#  'Giám sát',
#  'Giám sát bán hàng',
#  'Giám Đốc',
#  'Giám đốc',
#  'Giám đốc chi nhánh',
#  'Giáo  viên',
#  'Giáo Viên',
#  'Giáo viên',
#  'Giáo viên  tổ trưởng',
#  'Giáo viên Mầm non',
#  'Giáo viên THCS',
#  'Giáo viên THCS chính',
#  'Giáo viên mầm non',
#  'Giáo viên mầm non (Lao động hợp đồng)',
#  'Giáo viên trung học',
#  'Giáo viên.',
#  'Giảng viên',
#  'Hiệu Phó',
#  'Hiệu phó',
#  'Hiệu trưởng',
#  'Huấn luyện viên Cá nhân',
#  'Hộ lý',
#  'KCS',
#  'Khai thác than trong hầm lò',
#  'Kinh doanh',
#  'Kiểm hàng',
#  'Kiểm soát viên',
#  'Kiểm tra viên',
#  'Kế  toán',
#  'Kế Toán',
#  'Kế toán',
#  'Kế toán trưởng',
#  'Kế toán viên',
#  'Kỹ Sư',
#  'Kỹ Sư Xây Dựng',
#  'Kỹ sư',
#  'Kỹ sư xây dựng',
#  'Kỹ sư điện',
#  'Kỹ thuật',
#  'Kỹ thuật viên',
#  'Kỹ thuật viên sơn',
#  'Kỹ thuật viên trung cấp',
#  'Lao động phổ thông',
#  'Lái Xe',
#  'Lái máy',
#  'Lái xe',
#  'Lái xe Taxi',
#  'Lái xe tải',
#  'LĐPT',
#  'Lưu hóa các sản phẩm cao su',
#  'May Công Nghiệp',
#  'May công nghiệp',
#  'NHÂN VIÊN',
#  'NV',
#  'NV Bán hàng',
#  'NV Bảo vệ',
#  'NV Chứng từ',
#  'NV KD',
#  'NV Kỹ thuật',
#  'NV Tiếp Thị',
#  'NV bán hàng',
#  'NV giao hàng',
#  'NV kho',
#  'NV kinh doanh',
#  'NV lái xe',
#  'NVBH',
#  'Nhân Viên',
#  'Nhân Viên Bán Hàng',
#  'Nhân Viên Bán Hàng - Bình Định - Kv4',
#  'Nhân Viên Bán Hàng Trực Tiếp',
#  'Nhân Viên Bán hàng',
#  'Nhân Viên Giao Nhận',
#  'Nhân Viên Hỗ Trợ Kinh Doanh',
#  'Nhân Viên Lái Xe',
#  'Nhân Viên Sản Xuất',
#  'Nhân Viên Tiếp Thị',
#  'Nhân Viên Tư Vấn Tín Dụng - CD',
#  'Nhân Viên Văn Phòng',
#  'Nhân viên',
#  'Nhân viên - V01 - TP. Hà Nội',
#  'Nhân viên - V01 - TP. Hải Phòng',
#  'Nhân viên - V01 - TP. Hồ Chí Minh',
#  'Nhân viên - V01 - Tỉnh Bình Dương',
#  'Nhân viên - V01 - Tỉnh Hải Phòng',
#  'Nhân viên - V01 - Tỉnh Đồng Nai',
#  'Nhân viên - V02 - Tỉnh Cà Mau',
#  'Nhân viên - V02 - Tỉnh Cần Thơ',
#  'Nhân viên - V02 - Tỉnh Long An',
#  'Nhân viên - V02 - Tỉnh Quảng Ninh',
#  'Nhân viên - V02 - Tỉnh Thừa Thiên Huế',
#  'Nhân viên - V03 - Tỉnh Đồng Tháp',
#  'Nhân viên - V04 - Tỉnh Bình Thuận',
#  'Nhân viên - V04 - Tỉnh Nghệ An',
#  'Nhân viên - V04 - Tỉnh Thanh Hóa',
#  'Nhân viên An toàn lao động',
#  'Nhân viên Bán hàng',
#  'Nhân viên Bảo vệ',
#  'Nhân viên Bếp',
#  'Nhân viên CSKH',
#  'Nhân viên Chăm Sóc Khách Hàng',
#  'Nhân viên Giao nhận',
#  'Nhân viên KCS',
#  'Nhân viên Kho',
#  'Nhân viên Kho kiêm Hỗ trợ kỹ thuật',
#  'Nhân viên Kinh Doanh',
#  'Nhân viên Kinh doanh',
#  'Nhân viên Kế toán',
#  'Nhân viên Kỹ thuật',
#  'Nhân viên Lái xe',
#  'Nhân viên Lễ tân',
#  'Nhân viên Nhà hàng',
#  'Nhân viên Phục vụ',
#  'Nhân viên Phục vụ bàn',
#  'Nhân viên QC',
#  'Nhân viên S1',
#  'Nhân viên Sản xuất',
#  'Nhân viên Thao Tác',
#  'Nhân viên Trang Trí kiêm Thu ngân - Sim Số',
#  'Nhân viên Tư Vấn',
#  'Nhân viên VP',
#  'Nhân viên buồng',
#  'Nhân viên buồng phòng',
#  'Nhân viên bán hàng',
#  'Nhân viên bán hàng trực tiếp',
#  'Nhân viên bán vé',
#  'Nhân viên bảo trì',
#  'Nhân viên bảo vệ',
#  'Nhân viên bếp',
#  'Nhân viên cơ điện',
#  'Nhân viên giao hàng',
#  'Nhân viên giao nhận',
#  'Nhân viên giới thiệu sản phẩm',
#  'Nhân viên hành chính',
#  'Nhân viên hỗ trợ bán hàng',
#  'Nhân viên kho',
#  'Nhân viên kinh doanh',
#  'Nhân viên kiểm hàng',
#  'Nhân viên kiểm tra chất lượng sản phẩm',
#  'Nhân viên kế toán',
#  'Nhân viên kỹ thuật',
#  'Nhân viên lái xe',
#  'Nhân viên lái xe nâng',
#  'Nhân viên lái xe taxi',
#  'Nhân viên lập trình',
#  'Nhân viên lễ tân',
#  'Nhân viên nấu ăn',
#  'Nhân viên phát triển thị trường',
#  'Nhân viên phòng Sản xuất',
#  'Nhân viên phụ bếp',
#  'Nhân viên phục vụ',
#  'Nhân viên siêu thị',
#  'Nhân viên sản xuất',
#  'Nhân viên thao tác',
#  'Nhân viên thiết kế',
#  'Nhân viên thống kê',
#  'Nhân viên thủ kho',
#  'Nhân viên tiếp thị',
#  'Nhân viên trị liệu',
#  'Nhân viên tư vấn bán hàng',
#  'Nhân viên tạp vụ',
#  'Nhân viên văn phòng',
#  'Nhân viên văn thư',
#  'Nhân viên vận hành',
#  'Nhân viên vận hành máy',
#  'Nhân viên vận hành sản xuất',
#  'Nhân viên xếp ống sợi con',
#  'Nhân viên điểm giới thiệu dịch vụ (Xe máy)',
#  'Nhân viên điểm giới thiệu dịch vụ (Điện máy)',
#  'Nhân viên đổ sợi sợi con',
#  'Nhân viên đứng máy OE',
#  'Nhân viên-Hà Nội',
#  'Nhân viên-TPHCM',
#  'None',
#  'Nữ hộ sinh',
#  'Operator',
#  'Phó giám đốc',
#  'Phó phòng',
#  'Phụ May',
#  'Phụ việc',
#  'Phụ việc chuẩn bị',
#  'Phụ xế',
#  'Phục vụ',
#  'Phục vụ bàn',
#  'Quản lý',
#  'Thieu chuc danh tu du lieu 3s',
#  'Thiết kế',
#  'Thuyền trưởng',
#  'Thành hình các sản phẩm cao su',
#  'Thợ gõ rỉ sơn cơ giới',
#  'Thợ hàn',
#  'Thợ lắp',
#  'Thợ lắp ráp',
#  'Thợ may',
#  'Thợ máy',
#  'Thợ phụ',
#  'Thợ sửa chữa',
#  'Thợ điện',
#  'Thợ ủi',
#  'Thủ công',
#  'Thủ kho',
#  'Thủ quỹ',
#  'Tiếp viên',
#  'Tiếp Đón Khách Hàng',
#  'Trưởng bộ phận',
#  'Trưởng ca',
#  'Trưởng công an xã',
#  'Trưởng phòng',
#  'Trợ lý',
#  'Trợ lý hành chính bậc 1',
#  'TÀI XẾ',
#  'TàI Xế',
#  'Tài Xế',
#  'Tài chính - Kế toán',
#  'Tài xế',
#  'Tạp vụ',
#  'Tổ Trưởng',
#  'Tổ phó',
#  'Tổ trưởng',
#  'Tổ trưởng cắt',
#  'Văn Thư',
#  'Văn thư',
#  'Vận hành thiết bị lọc bụi điện  lọc bụi tay áo  vít tải bụi',
#  'Y sĩ',
#  'Y sĩ đa khoa',
#  'Y sỹ',
#  'Y sỹ y học cổ truyền',
#  'Y sỹ đa khoa',
#  'bảo vệ',
#  'cn',
#  'cn cơ khí',
#  'cn may',
#  'cn vận hành máy may',
#  'cnhân đóng nút',
#  'cnv',
#  'cán bộ',
#  'cán bộ văn phòng thống kê',
#  'cán sự',
#  'công nhân',
#  'công nhân LắP RáP MOTOR',
#  'công nhân May',
#  'công nhân chăn nuôi',
#  'công nhân chặt',
#  'công nhân in sơn',
#  'công nhân khai thác',
#  'công nhân kho',
#  'công nhân kiểm hàng',
#  'công nhân kỹ thuật. 1.14  bậc 1/15',
#  'công nhân lắp ráp',
#  'công nhân may',
#  'công nhân may cn',
#  'công nhân may công nghiệp',
#  'công nhân pha cắt',
#  'công nhân sản xuất',
#  'công nhân sản xuất lắc',
#  'công nhân thành hình',
#  'công nhân thủ công gia công lần 2',
#  'công nhân viên',
#  'công nhân vận hành máy may công nghiệp',
#  'công nhân vận hành máy thêu',
#  'công nhân xi mạ',
#  'công nhân đóng gói',
#  'công nhân đứng máy',
#  'cấp dưỡng',
#  'giáo viên',
#  'giáo viên mầm non',
#  'hiệu phó',
#  'kế toán',
#  'kỹ thuật',
#  'kỹ thuật viên',
#  'lao động phổ thông',
#  'lái xe',
#  'lập trình viên',
#  nan,
#  'nhân viên',
#  'nhân viên bán hàng',
#  'nhân viên bán hàng - kênh tt - l.1',
#  'nhân viên bảo vệ',
#  'nhân viên kinh doanh',
#  'nhân viên kiểm phẩm',
#  'nhân viên kỹ thuật',
#  'nhân viên lái xe taxi',
#  'nhân viên thao tác',
#  'nhân viên tiếp thị',
#  'nhân viên văn phòng',
#  'nv',
#  'phụ việc',
#  'thợ may',
#  'thợ phụ',
#  'thợ ủi',
#  'thủ quỹ',
#  'tài xế',
#  'tạp vụ',
#  'tổ trưởng',
#  'undefined',
#  'y sĩ',
#  'Điều dưỡng',
#  'Điều dưỡng trung học',
#  'Điều dưỡng viên',
#  'Điều hành ĐTT',
#  'Đóng gói',
#  'Đầu bếp'}

# %% [markdown]
# #### Unique values in Train

# %%
unique_values(train,'maCv')
# Out:
# (None                            13203
#  Công nhân                         766
#  công nhân                         465
#  Nhân viên                         304
#  Giáo viên                         215
#                                  ...
#  Nhân viên bộ phận  Khuôn mẫu        1
#  Nhân viên Injection                 1
#  Công nhân chuyền dán-AD             1
#  Công Nhân Dán Bù                    1
#  Giám sát viên                       1
#  Name: maCv, Length: 3066, dtype: int64,
#  None                            0.649722
#  Công nhân                       0.037695
#  công nhân                       0.022883
#  Nhân viên                       0.014960
#  Giáo viên                       0.010580
#                                    ...
#  Nhân viên bộ phận  Khuôn mẫu    0.000049
#  Nhân viên Injection             0.000049
#  Công nhân chuyền dán-AD         0.000049
#  Công Nhân Dán Bù                0.000049
#  Giám sát viên                   0.000049
#  Name: maCv, Length: 3066, dtype: float64)

# %% [markdown]
# #### Unique values in Test

# %%
unique_values(test,'maCv')
# Out:
# (None                    8795
#  Công nhân                490
#  công nhân                330
#  Nhân viên                180
#  Giáo viên                155
#                          ...
#  cnsx                       1
#  Phụ máy Cắt                1
#  Nữ hộ sinh Trung học       1
#  Công nhân cát bavia        1
#  NV kho                     1
#  Name: maCv, Length: 2124, dtype: int64, None                    0.651675
#  Công nhân               0.036307
#  công nhân               0.024452
#  Nhân viên               0.013337
#  Giáo viên               0.011485
#                            ...
#  cnsx                    0.000074
#  Phụ máy Cắt             0.000074
#  Nữ hộ sinh Trung học    0.000074
#  Công nhân cát bavia     0.000074
#  NV kho                  0.000074
#  Name: maCv, Length: 2124, dtype: float64)

# %% [markdown]
# ### 4. Compare Train and Test

# %% [markdown]
# Compare Unique values only in Train

# %%
values_only_in_set(train, test, 'maCv')
# Out:
# ({'thủ kho',
#   'Lao động phụ',
#   'Công nhân sửa chữa lại',
#   'Giao dịch viên Khối Khách hàng cá nhân\tPVcomBank Đồng Nai',
#   'Công nhân dán bóng',
#   'Giám sát Bán hàng',
#   'Bảo vệ tuần tra canh gác',
#   'Công Nhân Pha Cắt Lầu B',
#   'Giáo viên (Khối trưởng)',
#   'Lái xe cơ quan',
#   'Trưởng phòng chăm sóc khách hàng',
#   'CN. Đóng nút',
#   'Dược tá',
#   'Công nhân hoàn chỉnh giầy',
#   'Nhân viên-Cấp bậc 1',
#   'Nhân viên Sản Xuất',
#   'Chuyên viên  Phó Trưởng ban',
#   'Giáo viên trường mầm non bán công xã Liêm Thuận',
#   'Công nhân đồng bộ bán thành phẩm',
#   'chuyên viên',
#   'Phó Giám đốc xí nghiệp giặt',
#   'Bảo mẫu  C.ty TNHH GD Song Ngữ',
#   'Nhân viên phòng kỹ thuật Chất lượng',
#   'NV Phòng Kế toán',
#   'Điều dưỡng viên TYT TT Tân Dân',
#   'NV Bán hàng/CocaCola/Vùng 2',
#   'Nhân viên bàn',
#   'TP may 1',
#   'Công nhân gắn rập nhám',
#   'Công Nhân Đứng Máy (B)',
#   'Công nhân May Công Nghiệp',
#   'Giáo viên tổ phó tổ sinh hóa',
#   'Công Nhân CL1-L1',
#   'Đứng máy cán',
#   'Công Nhân Hàn',
#   'Công nhân Mài SF-mài cạnh',
#   'Nhân viên Thống kê đầy rỗng',
#   'Công nhân Chuẩn bị giầy',
#   'Nhân viên - V03 - Tỉnh Quảng Ngãi',
#   'Nhân viên phòng kế hoạch kinh doanh',
#   'Chủ tịch hội. Phụ nữ xã',
#   'Công Nhân Phụ Máy May Giầy',
#   'Công nhân kiểm râu',
#   'Phó phòng hành chính kế toán',
#   'Phó T Khoa',
#   'Nhân viên quan hệ khách hàng',
#   'NHÂN VIÊN KHO',
#   'Công nhân mài nước',
#   'Giáo viên - Tổ trưởng khối 4+5',
#   'Công nhân Phụ',
#   'Nhân viên hỗ trợ 1 (sơ chế)',
#   'Vận Hành Máy In Hoa Trên Trục  Trên Lưới',
#   'Gíao viên trường Tiểu học  Vàm Láng 2',
#   'Nhân viên bảo vệ chi nhánh hoà thuận',
#   'Công nhân quản lý vận hành lưới điện trung thế - Điện lực Con Cuông',
#   'thêu vi tính',
#   'Nhân viên văn phòng xưởng',
#   'Công Nhân May Chuẩn Bị',
#   'nhân viên giao hàng-giải phóng',
#   'Công nhân Phun ép',
#   'CN Xưởng chặt',
#   'công nhân phun sơn',
#   'Công Nhân Đóng Gói A 03',
#   'trung cấp tin',
#   'Coõng nhaõn boọ phaọn Nos G',
#   'Nhân viên bảo vệ kho dự trữ',
#   'công nhân _ xưởng may',
#   'Phó chủ tịch UBMT tổ quốc',
#   'Công Nhân Dán Bù',
#   'Nhân viên Hậu mãi',
#   'Phụ xe',
#   'Nhân viên thủ quỹ',
#   '25526 công nhân',
#   'Công nhân chế biến hải sản đông lạnh',
#   'Công nhân Đan dây',
#   'Trưởng Ca - V01 - TP. Hồ Chí Minh',
#   'MAY CÔNG NGHIỆP',
#   'nhân viên kinh doanh dự án samsung',
#   'trung cấp trắc địa  KTV đo đạc',
#   'CN khai thác mủ cao su - Nông trường Nghĩa Trung',
#   'Công Nhân Nguyên Liệu',
#   'Công Nhân Cắt May CN',
#   'NV-Tổ chức',
#   'Công nhân may bật 1/12',
#   'Nhân viên hóa mỹ phẩm',
#   'Công nhân chạy máy định hình',
#   'công nhân cơ khí sửa chữa máy công nghiệp',
#   'TBPT-CÔNG NHÂN ĐÓNG GÓI',
#   'Biên chế đặc biệt',
#   'Công nhân dán dính',
#   'Công Nhân Bậc 3/7',
#   'kỹ sư chăn nuôi',
#   'Công nhân thợ phụ',
#   'Nhân Viên QC',
#   'Vệ sinh công nghiệp',
#   'công nhân may  độc hại',
#   'Tài chính -Kế toán',
#   'may chuyền 12',
#   'cụng nhõn',
#   'Công nhân bộ phận',
#   'Công nhân tổ Chuẩn bị',
#   'kiểm hoá',
#   'Công Nhân Điện Tử',
#   'Công nhân Cơ động',
#   'Công nhân Khoan nổ',
#   'Công nhân sản xuất tủ lạnh',
#   'Chuyên viên tư vấn khách hàng qua điện thoại',
#   'Nhân viên - V04 - Tỉnh An Giang',
#   'bốc xếp',
#   'Gíao viên trường  tiểu học Tăng hoà',
#   'Công nhân  BPCT',
#   'Thợ phụ kiện',
#   'Nhân viên thu phí nhập chợ',
#   'Công nhân sản xuất nước khoáng',
#   'Điều dưỡng hạng IV',
#   'Phụ Xế',
#   'Công Nhân Bp Qc',
#   'công nhân là',
#   'CÔNG NHÂN KIỂM PHẨM',
#   'Công Nhân Đóng Túi',
#   'công nhân tổ Chà',
#   'công nhân lò hấp',
#   'Công nhân mài nút',
#   'công nhân đế 1',
#   'Công nhân  Cty CPCB Gỗ Đức Thành',
#   '73231/Unza/NVBH/GD NTTầng+ Khánh Hội+Lâm Văn Bền/Vùng',
#   'Nhân viên thu tiền',
#   'Công nhân chế biến tương ớt',
#   'Công nhân may hàng phổ thông',
#   'Công nhân dán mặt',
#   'Nghiên cứu viên  85% bậc 1/9',
#   'Kỹ sư XD cầu đường',
#   'Phó chủ tịch hội cựu chiến binh xã',
#   'công nhân tiếp nhận',
#   'CN vận hành máy đóng bao xi măng - PXTP',
#   'Hướng Dẫn Viên',
#   'Nhân Viên Thao Tác',
#   'LáI xe tải loại tảI tọng 36 tấn bậc 1/4',
#   'công nhân -may',
#   'Công nhân công việc thủ công khác ( dán tem  phối đôi  kiểm liệu )',
#   'Nhân viên - V02 - Tỉnh Lào Cai',
#   'tài xế xe Terberg',
#   'Trải vải',
#   'Công nhân DEÄT 3A',
#   'THợ MAY',
#   'Công nhân Trang Trí',
#   'Công nhân suất ăn công nghiệp',
#   'phụ xe cuốc',
#   'Công Nhân Đào Tạo',
#   'Phó Giám đốc',
#   'Công nhân vận hành máy và thiết bị hàn  sửa bản mạch',
#   'công nhân quét rác',
#   'NV Kỹ THUậT',
#   'Công nhân phòng Sản xuất 4',
#   'Giám sát giặt là',
#   'Nhân viên bán lẻ xăng dầu',
#   'công nhân BắN THẻ BàI',
#   'Cắt vải trong công nghệ may',
#   'Tổ phó may',
#   'Công nhân Gò hàn',
#   'Nhân viên làm việc HCM - Vùng 1',
#   'Công nhân Phụ may',
#   'Công nhân LĐPT',
#   'Cán sự văn hoá xã hội xã',
#   'Công nhân nông phom',
#   'Nhân viên Kho kiêm Hỗ trợ kỹ thuật - V03 - Tỉnh Thừa Thiên - Huế',
#   'Công nhân chế biến gỗ',
#   'Công nhân lắp ráp loa',
#   'Công nhân cơ khí sửa chữa ô tô  phụ xe',
#   'ÉP DA',
#   'Thợ nguội SCTBKT bậc 2',
#   'Thống kê  kế toán',
#   'Giáo viên cơ hữu',
#   'tổ phó tổ bộ môn điện tử',
#   'CNKT vận hành thiết bị sản xuất xi măng',
#   'Công Nhân Vận Hành Máy Nhuộm',
#   'công nhân sản xuất thức ăn thủy sản',
#   'Nhân viên - V02 - Tỉnh Bà Rịa - Vũng Tàu',
#   'Nhân Viên Phòng Kế Hoạch',
#   'Y sỹ - trưởng trạm-Trạm Y tế xã Bản cầm',
#   'Công nhân làm 3 ca',
#   'Mài Da',
#   'Nhân viên Kiểm soát chất lượng',
#   'Tăng mới theo Hợp đồng lao động số 13-2017/HĐLĐ  TM',
#   'Nhân viên giao nhận hàng hóa bậc 1/5',
#   'Nhân viên/Chuyên viên',
#   'Công nhân bộ phận sơn',
#   'Nhân viên - V02 - Tỉnh Lâm Đồng',
#   'Nhân viên Sơ chế',
#   'Công Nhân Phun Sơn',
#   'Công nhân đánh bóng dao thìa dĩa inox',
#   'Chuyên viên I Quan hệ khách hàng',
#   'Cơ khí',
#   'Trưởng nhóm kinh doanh',
#   'NV v?n hành máy',
#   'Nhân viên - V02 - Tỉnh Bắc Ninh',
#   'công nhân lắp ráp motor',
#   'Công nhân so  sửa bán thành phẩm  Công ty TNHH GG Việt Nam',
#   'Công nhân dây máy',
#   'Xử Lý',
#   'Công Nhân Kiểm Phẩm',
#   'Chuyên dùng',
#   'Công nhân đứng máy dệt sợi',
#   'NV kỹ thuật TKBT-Nha Trang  Khánh Hòa',
#   'Cụng nhõn may cụng nghiệp (may ba lụ  giỏ  tỳi xỏch)',
#   'NHÂN VIÊN GIAO HÀNG',
#   'Nhân viên Sau Bán Hàng kiêm Tư Vấn - V03 - Tx. Vĩnh Châu - Sóc Trăng',
#   'công nhân lắp đặt bậc 5/7  đội quản lý mạng',
#   'n.viên',
#   'NVVP',
#   'Công nhân NM Sợi 2',
#   'Nhân viên thu phí MTC',
#   'Công nhân chạy lò',
#   'Công nhân sơn treo',
#   'nnđh',
#   'Công nhân chạy máy cắt',
#   'Phó trưởng ban dân vận',
#   'công nhân ép đế',
#   'CN kiểm hóa (may công nghiệp)',
#   'Công nhân thử việc',
#   'CB Địa chính -XD',
#   'CN vận hành máy may-chuyền 10',
#   'NV Tạp vụ',
#   'Nhân viên  Tiếp thị qua điện thoại',
#   'NV kỹ thuật SWAP-Ninh Kiều  Cần Thơ',
#   'Công nhân máy screen',
#   'Nhân viên Injection',
#   'nử hộ sinh',
#   '002111-Công nhân',
#   'Công tác tại Vũng Tàu',
#   'Công nhân nạp liệu',
#   'Công nhânTest 2',
#   'nv kế toán',
#   'Tổ trưởng tổ 9',
#   'Weigh Bridge operator/ Nhân viên trạm cân',
#   'Kế toán;',
#   'công nhân cắt',
#   'Nhân viên kỷ thuật',
#   'Nhân viên Trang Trí kiêm Thu ngân - Sim Số - V02 - Tỉnh An Giang',
#   'công nhân phân xưởng hoàn chỉnh',
#   'Công nhân Sản Xuất tôm',
#   'Giáo viên Tâm lý trị liệu',
#   'Công nhân xưởng nhuộm',
#   'Hợp đồng - Ngạch Giáo viên Mầm non hạng III',
#   'Nhân viên phòng quản lý và TT sản phẩm',
#   'Công nhân điện kỹ thuật',
#   'Công nhân VH Lò hơi',
#   'Công nhân gấp  đóng gói  (may công nghiệp)',
#   'công nhân thêu',
#   'NHÂN VIÊN CƠ ĐIệN',
#   'Quản đốc',
#   'Công nhân khâu chặt',
#   'Công nhân duy tu  sữa chữa cầu đường sắt - Cung đường Mỹ Chánh',
#   'Nhân viên đứng máy sợi con',
#   'Nv may mẫu',
#   'Công nhân Phòng chế tạo',
#   'phục vụ nấu ăn',
#   'Chuyên viên dịch vụ khách hàng - Hà Tĩnh',
#   'Trung cấp cơ khí',
#   'Công nhân kiểm tra chất lượng (023102)',
#   'Thu? kho',
#   'cán bộ kỹ thuật',
#   'Nhân viên QC thiết bị đo',
#   'Trợ lÝ sản xuất',
#   'Công Nhân - Tốp - Xưởng 1',
#   'Công nhân Tạo hình ngói',
#   'Nhân viên phòng Kỹ thuật linh kiện',
#   'Công nhân đo đếm vảI may công nghiệp',
#   'NV hỗ trợ kỹ thuật - Lv2',
#   'Điều Dưỡng Tc',
#   'Trực phụ vận hành',
#   'Công Nhân Định Hình Mũ',
#   'Cán bộ KT',
#   'công nhân khai thác than hầm lò',
#   'Nhân viên điểm giới thiệu dịch vụ (Điện máy) - Nơi làm việc: Long An',
#   'CÔNG NHÂN RóT TƯƠNG',
#   'NHÂN VIÊN NHÂN SỰ',
#   'Chuyên Viên Hỗ Trợ Kinh Doanh',
#   'Công nhânép Đế Đi 3 Ca',
#   'Công nhân sơn tĩnh điện',
#   'nấu ăn',
#   'May Công nghiệp',
#   'Công nhân vận hành trạm bậc 5/7',
#   'Nhân viên phòng vé',
#   'Vận hành máy xúc ghạt bậc 3/7',
#   'Giáo viên tiếng anh.Trường Mầm non SCAVI',
#   'Công nhân ủi thành phẩm',
#   'Công nhân sửa chữa máy may công nghiệp',
#   'công nhân sản xuất sản phẩm cao su',
#   'Công nhân thao tác công đoạn thành hình',
#   'Công nhân vận hành máy may công nghiệp - A248482/A22',
#   'công nhân đế lớn',
#   'Tài xế lái xe taxi 5 ghế đến 8 ghế',
#   'Giáo viên hợp đồng',
#   'Điều hành xe',
#   'cnhân may cn',
#   'Lao động phổ thông',
#   'Nhân Viên Tổng Đài Thu Hồi Nợ - Bậc 1',
#   'Nhân Viên Bán Hàng - Bình Dương - Thị Xã Bến Cát - Kv1',
#   'Công nhân xếp dỡ',
#   'Nữ hộ sinh trung cấp bậc 1/12  khoa sản',
#   'Công nhân sản xuất nến',
#   'Công nhân may mẫu',
#   'Công Nhân ĐúC Đế(SX - A)',
#   'Nhân viên MáY MàI',
#   'Công Nhân Đứng Máy Thêu',
#   'Thủ kho vật tư  công cụ dụng cụ',
#   'Bí thư Đảng uỷ',
#   'CN đóng gói CN',
#   'CN Đề co',
#   'CN vận hành máy may (may công nghiệp)',
#   'Công nhân kiểm hàng đế lớn',
#   'CN pha chế',
#   'Nhân viên Sau Bán Hàng kiêm Tư Vấn - V04 -  Triệu Sơn - Thanh Hoá',
#   'Tổ trưởng Kéo xoắn',
#   'Công nhân đường dây',
#   'công nhân phụ hàn',
#   'Nhân viên Dịch vụ sau bán hàng - V04 - T. Nghệ An',
#   'Nhân viên - V04 - Tỉnh Tây Ninh',
#   'Công nhân Lắp Ráp',
#   'Phó phòng KD',
#   'Công Nhân Relift',
#   'Kế Toán Trưởng',
#   'CÔNG NHÂN Tiện  phay  bào',
#   'Nhân viên Kiểm ngân',
#   'Công nhân  NKAN',
#   'Công nhân sửa chữa thiết bị cơ điện trong hầm lò',
#   'Công nhân vô lon Flexible',
#   'CN may công nghiệp  Cty TNHH may Hiếu Tiên',
#   'Công nhân phòng kiểm tra chất lượng.',
#   'Công nhân bộ phận nhặt chỉ  hoàn thành',
#   'tổ phó  giáo viên',
#   'Công nhân khai thác mủ cao su  bậc 1/6',
#   'Công nhân PTO',
#   'lao động PT',
#   'công nhân gỗ',
#   'Nhân viên XN XN Lắp ráp',
#   'Nhân viên tư vấn dinh dưỡng (Vùng:I  -Ngạch: C.23 - Bậc: II)',
#   'Công nhân vận hành máy',
#   'NV. MR',
#   'Sale Assistant',
#   'Công Nhân BP Đóng Gói',
#   'Công nhân Cán cao su: Đứng máy 2 trục ở CCS',
#   'Công nhân TMIL X1',
#   'Kiểm tra và gia công sản phẩm',
#   'Nhân viên vận hành tập sự',
#   'Nhân viên bán lẻ XD',
#   'Trợ lý trưởng xưởng',
#   'Nhân viên may mẫu',
#   'Công Nhân May Công nghiệp',
#   'công nhân  chăm sóc cao su',
#   'Nhân viên Lái Xe',
#   'Nhân viên hướng dẫn game',
#   'Công nhân Máy lạng',
#   'Công nhân HLBU ỐNG ĐỨNG',
#   'Nhân viên - V04 - Tỉnh Trà Vinh',
#   'chuyền phó chuyền may CN',
#   'Quản lý công đoạn',
#   'Công nhân PX Điện gia dụng',
#   'Nhân viên Kinh Doanh (A)',
#   'Phó chỉ huy trưởng Quân sự',
#   'Kỹ Thuật Bảo Trì',
#   'Công nhân tổ sơn',
#   'Công nhân QLVH ĐZ  Truyền tải điện 500KV Đắk Nông',
#   'Nhân viên Thợ Mộc',
#   'công nhân sản xuất giầy Bộ phận pha cắt',
#   'Công nhân Chặt da liệu',
#   'Công nhân épmex',
#   'Chuyên Viên Phòng Tiếp Thị Truyền Thông',
#   'Công nhân sản xuất Bông',
#   'công ty tnhh yahon',
#   'Phụ kho',
#   'nvsx',
#   'Thủ kho vật tư thiết bị cơ khí sản xuất xi măng',
#   'Chủ tịch Hội Nông Dân Việt Nam',
#   'CN-DÁN HỢP',
#   'Nhân viên Máy Khoan Lỗ',
#   'GIáO VIÊN',
#   'Lái xe trọng tải từ 40 tấn trở lên',
#   'Công nhân cơ khí Nhà máy chế biến đồ gỗ xuất khẩu Hoà Xá',
#   'Công nhân bộ phận chà nhám',
#   'quản lí',
#   'Chủ tịch ủy ban mặt trận tổ quốc',
#   'Nv tạp vụ',
#   'Công nhân bộ phận thành hình',
#   'Kiểm Hàng',
#   'Trugn cấp kỹ thuật Vật lý trị liệu Phục hồi chức năng',
#   'BảO Vệ',
#   'CN-Dán gia cố',
#   'Nhân viên bán xăng dầu CHXD Số 1 - 124 Lê Duẩn - Phường 1 - Thị Xã Quảng Trị - Quảng Trị',
#   'Nhân viên Tư Vấn - V03 - Châu Thành - Tiền Giang',
#   'Lái xe sơ mi rơ mooc - phòng kế hoạch kinh doanh',
#   'CN Nguyên liệu',
#   'Hơp đồng Thu',
#   'Công Nhân Lò Nung',
#   'Công nhân tổ lắp ráp',
#   'Công nhân kỹ thuật viễn thông',
#   'Nhân viên - V03 - Tỉnh Ninh Bình',
#   'Phó Hiệu trưởng',
#   'Công nhân pha phao nhỏ C2',
#   'CÔNG NHÂN CắT Đế',
#   'công nhân thả liệu',
#   'Công nhân bộ phận gia công',
#   'Nhân viên sơn tĩnh điện',
#   'CN đánh số - BP Cắt',
#   'Nhân viên nghiệp vụ',
#   'Công nhân bán lẻ xăng dầu - CHXD Số 31',
#   'Cán sự Văn phòng thống kê',
#   'Công nhân kiểm tra linh kiện theo đúng tiêu chuẩn công việc và tiêu chuẩn kiểm tra',
#   'Bảo vệ tuần tra',
#   'CN Phụ',
#   'Công nhân  CB thủy sản',
#   'Chế tác viên',
#   'lái xe tải 15 tấn',
#   'Công nhân  Phụ May',
#   'Hộ lý khoa nội tim mạch',
#   'Phó chủ quản p.Hành chính',
#   'Lái xe đầu kéo',
#   'Nhân Viên Tư Vần  Công ty TNHH AKLC Việt Nam',
#   'Công Nhân Cạo Mủ bậc 1/6',
#   'Công nhân sản xuất  lắp ráp linh kiện điện tử',
#   'công nhân hiện trường sản xuất',
#   'Giám sát bộ phận sản xuất',
#   'SR - Nhân viên BH',
#   'Nhân viên sản xuất phòng gia công',
#   'công nhân may trực tiếp công nghiệp',
#   'Công nhân chuyền SP',
#   'Công nhân mài đá',
#   'CÔNG NHÂN CắT',
#   'Nhân viên thẩm mỹ',
#   'Chủ tịch Hội Chữ thập đỏ',
#   'Kỹ sư  Phòng Kỹ thuật 3',
#   'NV kiểm tra chất lượng',
#   'Công nhân mộc máy tại Bảo Minh',
#   'Cán bộ Ban tổ chức',
#   'Tổ trưởng tổ tạp vụ',
#   'Nhân viên tư vấn kỹ thuật thương mại',
#   'Nhõn viờn',
#   'Lái xe container trên 20 tấn',
#   'NVTT',
#   'Trình dược viên',
#   'Phụ may',
#   'Công nhân mặt hàng mới',
#   'Lái xe 5 tấn',
#   'Công nhân may khuyết cúc trong công nghiệp may',
#   'Công nhân quét rác đường phố',
#   'Công NhânA-L',
#   'nhân viên ánh sáng',
#   'Nhân viên Kiểm lỗi Phần mềm',
#   'Công nhân cà lăn cuối chuyền',
#   'công nhân kiểm tra chất lượng (kiểm hóa)',
#   'công nhân  gò giày  dép',
#   'Công Nhân Sơn bảo dưỡng chai gas',
#   'Nhân viên tổ bao gói  Công ty cổ phần Sữa Hà Nội  Quang Minh  Mê Linh  Hà Nội',
#   'Nhân viên An ninh kiểm soát',
#   'Giáo Viên Mầm Non Bậc 1/12',
#   'Vận hành máy ống hút màng co',
#   'công nhân phụ phẩm Fillet',
#   'Công nhân chuẩn bị ép',
#   'Tỉa Biên',
#   'Cán bộ khuyến nông cơ sở',
#   'Công nhân bao bản',
#   'Công nhân so  sửa bán thánh phẩm (may công nghiệp)',
#   'Nhân viên KTCN',
#   'Nhân viên Tư Vấn - V02 - Cẩm Phả - Quảng Ninh',
#   '1006481',
#   'Nhân viên Bán Hàng',
#   'Kỹ sư. Phòng vật tư-thiết bị y tế',
#   'Công nhân đánh xi',
#   'giáo viên  tổ phó',
#   'Cn-Xử Lý Tp',
#   'Làm mác',
#   'Công Nhân Quét Keo Chuyền Chuẩn Bị',
#   'Công nhân phòng in bao bì mỹ phẩm',
#   'Phó bí thư đoàn thanh niên xã Yên Thắng. ủy ban nhân dân xã Yên Thắng  huyện Lang Chánh  tỉnh Thanh',
#   'Phó bí thư Đảng uỷ',
#   'Công nhân sản xuất tất',
#   'Công nhân tráng men( làm việc 3 ca)',
#   'Công nhân đứng máy cắt CNC',
#   'Công nhân chuyền bàn',
#   'Công Nhân Chuẩn Bị',
#   'Công nhân sản xuất công nghệ',
#   'NV thu mua',
#   'Chuyên viên Văn Phòng',
#   'Văn thư lưu trữ  Phong Tong Hop',
#   'NV Kiểm tơ SC',
#   'Giáo viên  tổ phó',
#   'Công nhân cấp liệu',
#   'Công nhân lái xe vận chuyển đất đá và than tại khu vực khai thác mỏ',
#   'Phó Hiệu Trưởng. Trường Mầm non Xa Mát',
#   'Công nhân vận hành mày may',
#   'CN trảI vảI',
#   'Thợ Điện - Cảng Chùa Vẽ',
#   'Nhân viên vùng 3',
#   'Công nhân_Chuẩn Bị 5',
#   'Giáo viên  Trường Mầm non xã Lùng Vai',
#   'NV kỹ thuật TKBT',
#   'Nhân viên Phòng SXLR',
#   'Nhân viên vùng 2',
#   'Thư ký hành chánh',
#   'Công Nhân Máy Hai Màu 2',
#   'CC. ĐCXXD',
#   'lắp ráp',
#   'Công nhân kiểm tra chất lượng da',
#   'Công Nhân Phụ May',
#   'Điều dưỡng nha',
#   'Giáo viên tiểu học hạng II  mã V.07.03.07  Bậc 1 (85%)',
#   'Cửa Hàng trưởng',
#   'Công nhân sản xuất bánh kẹo',
#   'Công nhân là ( TP )',
#   'Công Nhân Cắt Tỉa',
#   'Nhân viên nông trường',
#   'Công nhân sản xuất nữ trang',
#   'xã đội phó',
#   'Công nhân bọc da',
#   'Nhân viên - V03 - Thanh Hoá',
#   'Giáo viên',
#   'Công nhân phòng kỹ thuật',
#   'NV Khối lương',
#   'Điều dưỡng khoa Ngoại chấn thương',
#   'Nhân Viên Thu Hồi Nợ',
#   'Nhân viên Bảo vệ Phòng HCNS',
#   'NV. Vận hành CCR',
#   'Nhân viên kinh doanh CSP',
#   'Nhân viên Thống kê',
#   'Công nhân Sản xuất Lắp ráp',
#   'Giáo viên trường THCS Thạnh Thới Thuận',
#   'Công nhân mài bóng',
#   'Cụng nhõn ki?m hàng',
#   'Công nhân cải tiến',
#   'CAO SU',
#   'Chuyên  viên',
#   'Nhân viên xét nghiệm',
#   'công nhân nung đồng',
#   'CB - Công nhân viên',
#   'Nhân viên in sơn',
#   'Công nhân dán decal khô',
#   'NV Sale AQUA Vùng 02',
#   'Thợ bế',
#   'Tổ trưởng thêu',
#   'Công nhân - TH.1',
#   'Nhân Viên văn Phòng',
#   'bóc xếp',
#   'Công nhân đội thoát nước',
#   'NVBH Kao - Tây Ninh',
#   'Công nhân sx phụ tùng ô tô',
#   'Kỹ sư  bậc 1 - VI.01',
#   'Kỹ sư cơ điện',
#   'công nhân sửa hàng 7',
#   'công  nhân đế CS- ép đế C',
#   'NVLX',
#   'Ban kiểm soát',
#   'Nhân viên quản gia',
#   'Giáo viên Trường mầm non Liên Sơn',
#   'LĐ Phổ thông',
#   'Công nhân sản xuất và lắp ráp Motor',
#   'Nhân viên Nhân viên xử lý hàng hóa - Kho Hải An - PKD08',
#   'kỹ Thuật Viên',
#   'CN VH máy may công nghiệp',
#   'Công nhân chăm sóc cà phê đội 8',
#   'Phó phòng Giáo dục',
#   'Công Nhân Vận Hành Công Nghệ Clo Lỏng Thuộc Px Clo',
#   'Công nhân khâu in',
#   'COD',
#   'Nhân viên bảo hành',
#   'CN chăm sóc',
#   'Viên chức - Chi nhánh Văn phòng Đăng ký đất đai huyện Đà Bắc',
#   'Diễn Viên',
#   'Phó chủ nhiệm',
#   'Công nhân-Máy ép cao tần kỹ thuật cao',
#   'Công nhân bao bì XN Thắng Lợi',
#   'thợ máy',
#   'nữ hộ sinh',
#   'Lưu trữ viên trung cấp',
#   'y tá chính B12/12',
#   'Công nhân tạo hạt',
#   'Kiểm Phẩm',
#   'Công nhân cắt và bao ép',
#   'Chuyên viên văn phòng thống kê  phụ trách nội vị  cải cách hành chính  thi đua khen thưởng',
#   'THỢ HÀN',
#   'Nhân viên - V03 - CN Trà Vinh',
#   'Chuyên viên tư vấn',
#   'Công nhân hàn gia công lắp ráp',
#   'Công Nhân Bảo Trì',
#   'CN Chế biến TS',
#   'Nhân viên thủ kho -  Làm việc tại Đà Lạt  Lâm Đồng',
#   'Thợ hồ',
#   'Công nhân bộ phận công vụ',
#   'Giáo viên  - Mầm non Thống Nhất',
#   'Thủ quỹ cơ quan bậc 1/12',
#   'Kỹ thuật viên đánh máy',
#   'Công nhân Máy dập',
#   'CÔNG NHÂN ÉP PHUN',
#   'Phó bí thư Đảng uỷ xã',
#   'cn quấn',
#   'Nhõn viờn kinh doanh',
#   'Nhân viên kiểm phẩm',
#   'Nhân viên báo cáo',
#   'Nhân viên - Trường Tiểu Học Tân Hội B',
#   'Công nhân vòng ngoài',
#   'Chỉ huy Phó',
#   'Mài nhẵn mặt da  lạng da',
#   'Điều Hành Kinh Doanh',
#   'Chuyên viên  Xí nghiệp Kinh doanh số 2',
#   'Trợ lÝ Trưởng BP. Dịch vụ khách hàng',
#   'Công Nhân Vệ sinh máy IP',
#   'Nhân viên Tư Vấn - V01 - TP. Hà Nội',
#   'công nhân in di động',
#   'Công nhân kỹ thuật Phòng cơ khí',
#   'hướng dẫn  viên du lịch',
#   'công nhân mài nhẵn mặt da lạng da',
#   'Giáo viên-khối trưởng',
#   'Nhân viên Tiếp Đón Khách Hàng - V04 - Tỉnh Bình Định',
#   'May C9',
#   'cán sự  thanh tra xây dựng',
#   'Lái xe tải &gt; 25 tấn',
#   'Nhân viên bán hàng kiêm thu ngân',
#   'nvkd',
#   'Xã Đội trưởng',
#   'Nhân viên - V04 - Đắc Lắk',
#   'Công nhân Tẩy Phân xưởng Sơn',
#   'Công nhân dán trang trí 3 sọc',
#   'K? thu?t viờn',
#   'Công nhân BP Đánh Bóng',
#   'Công nhân Tạo phôi',
#   'Công Nhân Chuyền Chuẩn Bị',
#   'Sản xuất nội dung',
#   'Công nhân phụ máy thêu',
#   'Thợ Lạng',
#   'Giáo viên Trường MN Huỳnh Kim Phụng',
#   'Kỹ sư QA/QC',
#   'Kế Toán',
#   'Công nhân trồng chăm sóc cà phê',
#   'Công Nhân Cắt 3',
#   'Nhân viên an ninh',
#   'giáo viên trung học cơ sở hạng II bậc 1/9 hưởng 85%',
#   'Công nhân vận hành máy may (May công nghiệp- may mẫu)',
#   'CN Cấp dưỡng',
#   'giaó viên',
#   'công nhân phụ sơn da',
#   'Công Nhân Bảo Vệ',
#   'CN Phun sơn',
#   'Nhân viên phòng Kỹ thuật chất lượng',
#   'Lái xe Tải (tổng tải trọng dưới 5 tấn)',
#   'Công nhân kiểm tra chất lượng  tổ thu hóa',
#   'Nhân viên Vận hành xe nâng hạ',
#   'Bảo vệ rừng',
#   'Công nhân may công nghiệp  Tổng công ty may Nhà Bè-CTCP',
#   'Công nhân may trực tiếp công nghiệp',
#   'Nhân viên vệ sinh',
#   'Phan loai  kiem tra san pham',
#   'Trưởng TT',
#   'CB Đài truyền thanh',
#   'Nv đổ sợi sợi con',
#   'Công nhân gò máy',
#   'NHÂN VIÊN KINH DOANH',
#   'Công nhân xây dựng',
#   'Quản lý kinh doanh',
#   'Vận hành dây chuyền sợi',
#   'Nhân Viên Bảo Trì Nhà Máy',
#   'Công nhân may nối thân',
#   'Công nhân Bị Liệu A',
#   'Công nhân Máy ép  Tổ Máy ép',
#   'Công nhân kiểm tra chất lượng may công nghiệp',
#   'CÔNG NHÂN CHÀ NHÁM',
#   'Nhân viên lái xe cuốc',
#   'NV KẾ TOÁN',
#   'Công chức tư pháp hộ tịch',
#   'Tư vấn bán hàng',
#   'Công nhân chế biến thủy sản đông lạnh',
#   'Công nhân cưa',
#   'Công Nhân Chà Râu Mèo',
#   'NHÂN VIÊN BÁN HÀNG',
#   'Công nhân phân xưởng pha cắt',
#   'Nhân viên kỹ thuật địa chất',
#   'Nhân viên tổ kính cường lực',
#   'Công nhân đế',
#   'B.vệ',
#   'Nhân Viên BV',
#   'Công nhân mài nhẵn mặt da',
#   'ép đế',
#   'Bôi keo',
#   'Công nhân Phòng Sản xuất',
#   'Công nhân Mạ kẽm - Bậc 1/5',
#   'Công Nhân Đánh Cát',
#   'công nhân cắt gạch',
#   'CN vận hành máy khoan địa chất',
#   'Nhân Viên Giao Nhận Siêu Tốc',
#   'Công nhân phân xưởng nhuộm',
#   'Công nhân khai thác mủ',
#   'NV Quan hệ KHCN',
#   'công nhân xây lắp điện',
#   'SàNG  SấY HOá CHấT PHốI LIệU CAO SU',
#   'công nhân bảo vệ kho vật liệu nổ',
#   'Nhân viên thu tiền vệ sinh',
#   'Công nhân quét keo  dán đế',
#   'Worker(CN)',
#   '135',
#   'Giáo viên - Tổ trưởng',
#   'Chuyên viên Kỹ thuật - Sản xuất',
#   'Nhân viên Thu nợ Hiện trường',
#   'cn bốc xếp',
#   'Nhân viên Bán vé',
#   'Nhân viên - V03 - Tỉnh Vĩnh Phúc',
#   'Bí thư Đoàn Thanh niên cộng sản Hồ Chí Minh xã',
#   'Công nhân Mài',
#   'NHÂN VIÊN SINH QUảN',
#   'Công nhân nhà ăn',
#   'Nhân viên Phục vụ khách hàng',
#   'Bếp trưởng',
#   'Điều dưỡng TH',
#   'Chuyên viên KD',
#   'nv giao nhận',
#   'Nhân viên kế toán  Phòng Kế toán',
#   'Giáo viên trường trung học cơ sở Phan Bội Châu',
#   'CÔNG NHÂN CHÀ NHÁM',
#   'cn may 3',
#   'Lái xe vận chuyển bê tông',
#   'Đội phó đội sản xuất',
#   'Công nhân hậu cần nguyên phụ liệu',
#   'Giáo Viên Trường THCS Phú Tân',
#   'C.n Wood',
#   'Nhõn Viờn  Đội Bảo Vệ',
#   'Điều dưỡng Cao đẳng',
#   'Công nhân cắt hàng',
#   'Công nhân Là chuyền',
#   'Công nhân  cán thép',
#   'NV Thu cước',
#   'Nhân viên bán hàng Nhà sách Thanh Niên',
#   'Nhân viên đặt phòng và tổng đài',
#   'Công nhân  tiện phay  bào  khoan cắt gang thép',
#   'Công nhân tổ cơ điện',
#   'Nhân viên Dealer',
#   'Nhân viên Kinh doanh  Bưu điện Trung tâm thành phố Vinh',
#   'CN tổ Đóng gói 1 - NMSX Dược phẩm',
#   'phục vụ',
#   'Công nhân bộ phận vỏ lụa tay',
#   'Công nhân phòng In',
#   'Nhân viên Chà Nhám',
#   'Giáo viên MNNCL (LĐHĐ)',
#   'CN Tạo Hình',
#   'công nhân tổ kiểm tra',
#   'Kiểm Giày',
#   'Kế toán ( LĐHĐ)',
#   'Công nhân sấy  Vo viên  đóng bao NPK(NN-ĐH; CN Long An)',
#   'Nhân viên kiểm tra chất lượng',
#   'Nhân viên Tiếp Đón Khách Hàng',
#   'Nhân viên Kho Điện Máy',
#   'Công nhân- gấp biên',
#   'Thợ sửa chữa  bảo trì cơ điện chính',
#   'Công nhân Chuẩn bị - Lắp ráp 16',
#   'Công Nhân Nguyên Vật Liệu',
#   'Giáo viên Tiếng Anh',
#   'cn đường dây',
#   'Dịch vụ',
#   'Công nhân Hoàn thiện',
#   'Công Nhân Xử Lý Nước thải',
#   'Nhân viên văn phòng  PHòNG KINH DOANH',
#   'Trưởng trạm',
#   'CN Nhuộm',
#   'Nv KCS',
#   'Tổ trưởng chuyền sản xuất điện thoại  thiết bị điện tử viễn thông - Phòng Sản xuất',
#   'Tiếp viên bậc 1/5',
#   'y sĩ y học cổ truyền',
#   'CÔNG NHÂN LẮP RÁP ĐIỆN TỦ;',
#   'Công nhân bộ phận Nos F',
#   'Nhân viên đóng thùng',
#   'Trưởng ca sản xuất - Bộ phận sản xuất',
#   'Gíao viên',
#   'Nhân viên kỹ thậut',
#   'Nhân viên Kho kiêm Hỗ trợ kỹ thuật - V04 - Hàm Yên - Tuyên Quang',
#   'Nhân viên Kế Toán',
#   'Công nhân may công nghệp',
#   'Kỹ sư phát triển sản phẩm',
#   'Cán sự bậc 5/12  phòng kế toán - tài vụ',
#   'Lái máy xúc 450 dung tích gầu 1.9 khối',
#   'Công nhân-đóng gói',
#   'Phụ lái đầu máy xe lửa chở than',
#   'Nhân viên Cảnh quan',
#   'Công nhân bộ phận Multi casting',
#   'Lái máy xúc dưới 4m3/gầu',
#   'Công nhân phụ thêu',
#   'Nhân viên sợi nhân tạo',
#   'Công nhân máy dán',
#   'Nhân viên huấn luyện',
#   'Công nhân Nhuộm F1',
#   'Công nhân xi mạ',
#   'Công nhân nhà máy cán thép',
#   'Lái xe xúc lật',
#   'Nhân viên sửa chữa bảo trì ngoại vi và thiết bị',
#   'NV Phục Vụ',
#   'Công nhân sản xuất dây điện xe hơi',
#   'Công nhân đội chăm sóc vườn hoa',
#   'Trưởng phòng kỹ thuật',
#   'Công nhân bộ phận đóng gói',
#   'trợ lý bộ phận phun sơn',
#   'Công Nhân  ZY0172',
#   'Công nhân sản xuất loa điện thoại di động',
#   'CN Bảo trì điện',
#   'Điều Hành Bưu Cục',
#   'NV VP',
#   'công nhân tổ mài',
#   'Văn phòng thống kê',
#   'CN cấp đông',
#   'NV HỔ TRỢ KT  LÀM VIỆC TẠI BÌNH DƯƠNG  VÙNG 1',
#   'nhân viên vệ sinh  BVĐK cửa đông',
#   'Công nhân lắp ráp Chassis',
#   'Công nhân làm giầy',
#   'Công nhân sản xuất máy in  máy fax  linh kiện  thiết bị điện tử  các loại khuôn',
#   'cán bộ KCT',
#   'CNVH dây chuyền sợi',
#   '2983',
#   'BẢO MẪU',
#   'Y tế học đường',
#   'công nhân phân xưởng đùn ép',
#   'Giám Sát BH Tổng hợp',
#   'Giao dịch viên Bưu điện Thành phố Cao Lãnh',
#   'Nhân viên - Văn Phòng',
#   'TRợ Lý VĂN PHòNG',
#   'Công nhân cơ lý',
#   'Nhân viên Bảo trì tại các trang trại  trung tâm bán heo',
#   'Công Nhân Vận Hành Máy May Công Nghiệp',
#   'Công nhân ép Máy Caochupo',
#   'Nhân viên vệ sinh khu vực công cộng',
#   'Nhân viên chấm hình',
#   'Phụ Việc',
#   'CÔNG NHÂN ĐứNG MáY ĐáNH ốNG',
#   'Công nhân vận hành dây chuyền sợi (Máy ghép thô)',
#   'Công nhân kỹ thuật chăn nuôi',
#   'Nhân viên hồ bơi',
#   'Công nhân Cắt Jumbo',
#   'Công nhân chuyền Gomuneri',
#   'CN Khai thác than hầm lò',
#   'đổ sợi cho máy thô',
#   'Cán bộ nhà đất',
#   'C.Nhân/Lr Mdf',
#   'Công nhân So  sửa bán thành phẩm máy may công nghiệp - Bộ phận May',
#   'VSCN',
#   'Công nhân phòng Sản xuất linh kiện điện tử',
#   'Công nhân nhổ giày',
#   'giám đốc KD',
#   'Thủ kho chính',
#   'Công nhân bộ phận sản xuất',
#   'kỹ sư tin học',
#   'công nhân  Hàn',
#   'Công nhân chế biến',
#   'Công nhân đế trung',
#   'ép Suất  Thành Hình',
#   'Đầu lò sấy B1',
#   'Công nhân quét hóa chất',
#   'Nhân viên Hành chính',
#   'Là  GấP  ĐóNG GóI (MAY CÔNG NGHIệP)',
#   'Công nhân đóng gói 3 ca',
#   'Giáo viên hợp đồng Trường Mầm non 22/12',
#   'Công nhân Kéo dây đồng và nhôm',
#   'NV Bảo vệ  TP HCM',
#   'Công nhân phụ may máy công nghiệp',
#   'CN xử lý rác sinh hoạt',
#   'nhân viên quản lý',
#   'Nữ hộ sinh trung cấp  Trạm y tế Khánh Hải',
#   '2853',
#   'Công nhân Dệt Tất',
#   'Thủy thủ',
#   'Nhân viên tiếp đón',
#   'CÔNG NHÂN PHụ MAY',
#   'Kỹ thuật hiện trường',
#   'Công nhân Tinh 4',
#   'Công nhân VHMM - LĐ loại 4',
#   'Công nhân sản xuất VLXD',
#   'Văn Phòng - Thống Kê',
#   'Thủ kho thành phẩm',
#   'Công nhân Tổ ép',
#   'Đóng Gói - Kíp C1',
#   'Công nhân_Phụ việc',
#   'Chiếu Xạ - Thành Hình',
#   'Công nhân sửa chữa cơ điện trong hầm lò',
#   'Công nhân lao động phổ thông  CN Sông Đà 6.03',
#   'Nhân viên lái xe tải trọng 5 tấn',
#   'Công nhân cắt phá  cắt gọt (may công nghiệp)--Mã NNĐH--023100',
#   'Công Nhân cơ khí',
#   'Nhân viên Marketing',
#   'P. giám đốc',
#   'Công nhân cắt đai - gọt hàng',
#   'nhân viên y sỹ',
#   'CN- May giày',
#   'Phóng viên',
#   'Trợ lý giám sát',
#   'công nhân lắp ráp điện gia dụng',
#   'Nhân viên Locker (Golf)',
#   'công nhân QC1',
#   'Thực tập sinh thương mại',
#   'CÔNG NHÂN (QC FIN F2)',
#   'Cán bộ kỷ thuật trạm thú y TP Vị Thanh',
#   'CN Vận hành MMCN',
#   'QL Sản Xuất',
#   'Dược sỹ đại học',
#   'Nhân viên kỹ thuật chăn nuôi  chăm sóc gia súc  gia cầm',
#   'Kỹ thuật viên Quản lÝ Chất lượng',
#   'Kỹ Thuật',
#   'Công nhân gia công 2',
#   'Bác sỹ trực tiếp khám điều trị bệnh nhân cấp cứu',
#   'NV IT',
#   'Công nhân đứng máy chặt kv Cán cao su',
#   'NVB.Hàng',
#   'Nhân viên cụng trỡnh',
#   'nhân viên vật tư',
#   'Chuyên Viên',
#   'kế toán trưởng',
#   'Công nhân nối thân ruột phích',
#   'CN Chăm sóc cao su',
#   'Công Nhân - Dán Đế',
#   'Quản lý bán hàng',
#   'CÔNG NHÂN ĐóNG ĐINH',
#   'Địa chính - xây dựng',
#   'Thư ký',
#   'Công nhân định hình cá',
#   'Nhân Viên Mua Hàng',
#   'Nhân Viên Kỹ Thuật',
#   'Nhân viên spa',
#   'Phó bí thư đoàn thanh niên',
#   'công nhân đế cao su',
#   'Quản Lý',
#   'Nhân viên kinh doanh- dự án SS',
#   'Nhân viên phòng chất lượng',
#   'Cụng Nhõn',
#   '56743- NV Sales DSMs - Tiền Giang - Vùng 02',
#   'Nhân viên Bán hàng tại Hà Nội',
#   'Nhân viên kinh doanh kênh trả góp',
#   'Công nhân quét keo',
#   'Công nhân may Công nghiệp',
#   'Nhân viên quản lÝ lớp học',
#   'Phó phòng tài chính KH',
#   'Thủ kho Bao bì',
#   'nhân viên p.nhân sự',
#   'Giáo Viên Mầm Non. Trường MN Ba Ngạc',
#   'Nhân viên - V03 - Tỉnh Tiền Giang',
#   'Nhân viên điểm giới thiệu dịch vụ (Điện máy) - Nơi làm việc: Thừa Thiên Huế',
#   'Công nhân sản xuất phụ tùng ô tô',
#   'Công nhân bóc lụa',
#   'Nhân viên sản xuất - Chi nhánh Trà Vinh',
#   'điều dưỡng',
#   'Nhân viên Bảo mẫu',
#   'CBKT',
#   'Công nhân lắp ráp cabin',
#   'Công nhân khâu chuẩn bị',
#   'Công Nhân May Công Nghiệpline 17 F2',
#   'LĐPT X6CNV - CHà NHáM KIểM',
#   'Nhân viên tiếp thị bia  phòng kinh doanh Bia',
#   'Nhân Viên cơ khí',
#   'Trợ lý phòng IE',
#   'Lái máy xúc rác',
#   'Công nhân đại tu cầu đường sắt',
#   'Quản lý Khách hàng',
#   'Nhân viên nghiệp vụg',
#   'Công nhân may mũi giầy',
#   'Công nhân bộ phận ép',
#   'Công Nhân Định HÌnh',
#   'Nhân viên an ninh kiểm soát',
#   'Công nhân Phết keo đế và mũ giầy',
#   'Giám định viên',
#   'Nhân viên tổ bảo trì',
#   'công nhân đế',
#   'Công Nhân sữa chửa và bảo trì máy dệt',
#   'Công nhân Rải tôm',
#   'VN.5061',
#   'Nhân Viên Cung ứng',
#   'chuyên viên QHKHDN (RO)-01',
#   'Công nhân hình ảnh',
#   'công nhân chế tạo',
#   'CN  VHMM',
#   'Công nhân hàn bậc 3/7',
#   'Nhân viên - V04 - Tỉnh Quảng Ninh',
#   'NV VH hệ thống lưới lọc nghiêng',
#   'Công nhân-vệ sinh last',
#   'công nhân làm mẫu ghế',
#   'lấy dấu',
#   'Công nhân trồng chăm sóc thu hái chè',
#   'Công nhân đứng máy thêu',
#   'Công nhân sản xuất bánh',
#   'Giáo viên trường Mẫu giáo Krông Năng',
#   'Công Nhân Trộn Nguyên Liệu',
#   'CN bán lẻ xăng  dầu (049003)',
#   'Công nhân chỉnh lý (RB)',
#   'Bảo vệ  trường tiểu học Long sơn',
#   'Cửa hàng trưởng',
#   'CĐ Dược',
#   'Công nhân CN Rạch Giá',
#   'Công nhân hoa công',
#   'Phó Trưởng phòng',
#   'Giáo viên MN Vĩnh Hoà',
#   'công nhân sản xuất xơ tổng hợp',
#   'kỹ sư',
#   'Nhân viên bảo vệ dự án',
#   'Chuyên viên cao đẳng  bậc 1/10 mã số 01a.003',
#   'Công nhân điện chiếu sáng',
#   'Bán hàng (phường Bình Trị Đông B  quận Bình Tân  TPHCM)',
#   'CN  May CN',
#   'Nhân viên -  V03 - CN  Bình Định',
#   'Nhân viên giao hàng kỹ thuật',
#   'Nhân viên tổng đài',
#   ...},
#  2511)

# %% [markdown]
# Compare Unique values only in Test

# %%
values_only_in_set(test, train, 'maCv')
# Out:
# ({'Nhân viên phòng Lab',
#   'Trưởng phòng điều dưỡng bệnh viện đa khoa Tân Thạnh',
#   'Giáo viên trường  mẫu giáo Tân Bình 2',
#   'Gia công thủy tinh',
#   'Công nhân sản xuất máy giặt',
#   'CN CUỐN DA',
#   'K.ĐịNH VIÊN X5',
#   'Kế toán tổng hợp',
#   'Công nhân cắt PVC',
#   'A1.9III-3/7',
#   'công nhân sơn',
#   'KTV Sơn',
#   'CN Mở nắp-Lấy đế - Xưởng Đế PU',
#   'Nhân viên giao hàng - Chi nhánh Đồng Văn',
#   'Công nhân kho thành phẩm',
#   'ĐTV',
#   'Kỹ thuật viên trung tâm cấp 1',
#   'Cán bộ KD kiểm tra KHSDĐ',
#   'Công nhân Vận Hành máy Công ty Thanh Sơn Hóa Nông',
#   'Nhân viên - V03 - Tỉnh Bắc Giang',
#   'công nhân mực',
#   'công nhan quét dọn',
#   'Tổ trưởng chuyên môn',
#   'giáo viên THCS quyết tiến',
#   'Dược sỹ trung học cơ sở cấp phát thuốc Methadone Xã Ma Thì Hồ',
#   'KTV bảo trì',
#   'Tuyên truyền viên',
#   'CÔNG NHÂN-Tổ cào sớ - Xưởng 3',
#   'Nhân viên làm phòng',
#   'Công nhân lò hấp cá',
#   'Công nhân làm việc theo chế độ 03 ca',
#   'Công nhân Sắp xếp hàng lên container',
#   'Chuyên viên phiên dịch tiếng Nhật.',
#   'Công nhân pha phao nhỏ A',
#   'CÔNG NHÂN ĐÓNG ĐINH',
#   'NV Vận Hành SX II-Đóng Gói',
#   'Công nhân Hàn cổ góp',
#   'Công nhân hậu cần sản xuất',
#   'Nhân viên phòng Hành chính nhân sự',
#   'Nhân viên nhận mẫu (Sample reception)',
#   'nhân viên kinh doanh  Phòng kinh doanh',
#   'Nhân Viên Giám Sát Cảnh Quan',
#   'cn toà nhà l',
#   'Phó quản đốc máy  gầm  điện',
#   'kiểm tra chất lượng',
#   'Công nhân công nghệ',
#   'Công nhân lái máy nông nghiệp-Xí nghiệp Cơ giới Nông nghiệp',
#   'Nhân Viên Bán Hàng - Tp. Hồ Chí Minh - Kv1',
#   'Tổ Phó  Chuyền 03',
#   'CN Se sợi',
#   'Phụ trách Kiểm tra Đảng',
#   'Nhân viên Phòng Hành Chính - Nhân Sự',
#   'Công nhân Fillet',
#   'Nhân viên phòng Thiết bị',
#   'Công nhân cắt tỉa',
#   'KTV xét nghiệm',
#   'CN-vệ sinh last',
#   'NV chứng từ - Q.Bình Thạnh',
#   'Nhân viên Cơ điện',
#   'Cán bộ văn hoá xã hội.',
#   'Công Nhân Sản Xuất Gạch Ngói Tổ ép Máy',
#   'Tiện CNC',
#   'Nhân viên tòa nhà',
#   'Văn hóa  thể thao',
#   'NV Kế toán',
#   'Cửa hàng trưởng  CNBC Viettel Vĩnh Long',
#   'Nhân viên Kỹ  thuật',
#   'Công Nhân Sản Xuất Phốt',
#   'Công nhân là  gấp  đóng gói',
#   'TC Sửa chữa ô tô xe máy',
#   'Kế TOáN',
#   '308030139',
#   'Nhân viên may',
#   'cán bộ công nhân viên',
#   'Quản lý bán hàng khu vực',
#   'Tổ phó may 5',
#   'Thu ngân',
#   'Công nhân Hàn điện  hàn hơi',
#   'CN Lao động hỗ trợ',
#   'INTERNS',
#   'nv qaht',
#   'Đóng Gói - Kíp A2',
#   'CN SOFA',
#   'Nhân Viên Phòng Vật tư',
#   'Nhân viên An Ninh',
#   'công nhân may phân xưởng may II',
#   'Phụ trách XDĐSVH Cơ Sở',
#   'kỹ sư tư vấn thiết kế bậc 1/8',
#   'giáo viên tiểu học cao cấp bậc 1',
#   'Văn Phòng - Thống Kê (Mn:01.003)',
#   'Nv bán hàng tại Cần Thơ',
#   'Nhân viên kỹ thuật TTVT',
#   'Công nhân gấp xếp trong dây chuyền may công nghiệp',
#   'Công nhân pha màu',
#   'Nhân viên đào tạo kĩ thuật (Phòng Đóng Gói)',
#   'Nhân Viên Văn Thư',
#   'Nhân viên phục vụ khách hàng',
#   'CÔNG NHÂN MÁY ÉP',
#   'Trợ lý đặt hàng',
#   'Nhân viên vận hành hệ thống lạnh',
#   'CN kiểm tra',
#   'Công nhân Khuôn',
#   'Công Nhân vận hành máy May Công nghiệp',
#   'Công nhân sản xuất xưởng tiện',
#   'Nhân viên phòng Kế hoạch thị trường',
#   '68357- NV Sales Aqua -Vùng 02',
#   'Công nhân BP Digital',
#   'Lái xe trộn bê tông (xe tải từ 7 5 tấn đến dưới 20T)',
#   'Công nhân SX hình ảnh',
#   'Văn thư - thủ quỹ',
#   'Phó bí thư ĐTN',
#   'công nhân trồng mía',
#   'Công Nhân sửa cá',
#   'Nhân viên Điều Hành Điểm Tiếp Thị',
#   'công nhân cạo mủ',
#   'Giáo viên  kiêm tổ trưởng',
#   'Công nhân chế tạo',
#   'Giáo viên MN - Tr  MN Thị Trấn',
#   'Tư Vấn Viên - CN Đà Nẵng',
#   'Công nhân chế tạo  gia công  sữa chữa thiết bị sản xuất xi măng - P. cơ khí động lực',
#   'Công nhân vận hành máy cắt',
#   'nhân viên nhà hàng',
#   'giám đốc',
#   'Công nhân kiểm phẩm',
#   'Công nhân KCS thành phẩm',
#   'Nhân viên Phục vụ Hồ bơi - Khối Lễ Tân  Buồng Phòng  Giải Trí',
#   'Thực tập giám sát khu vực',
#   'Y Tá trung học khoa Nhi',
#   'Công nhân Phòng Đảm bảo chất lượng Tủ lạnh',
#   'Nhân viên cơ khí chỉnh máy',
#   'Điện thoại viên',
#   'Công nhân Kho Canon',
#   'hộ lý',
#   'Công nhân kiểm tra chất lượng van',
#   'Thợ dệt',
#   'Chuyên viên phục vụ tại chỗ',
#   'Thợ Điện',
#   'CN vận hành băng tải than',
#   'cnhân',
#   'Điều dưỡng trung học Lão khoa',
#   'Công nhân dệt may công nghiệp',
#   'nhân viên hợp đồng',
#   'Nhân viên đứng máy',
#   'Công nhân sửa chữa đường sắt',
#   'Công nhân chế biến thủy sản đông lạnh  bậc 1/6',
#   'Máy trưởng tàu sông hạng nhất trên 90CV',
#   'Nhân viên mùa vụ Dịch vụ khách hàng',
#   'Nữ hộ sinh Trung học  Nhân viên hợp đồng Khoa Phụ sản',
#   'Bảo mẫu',
#   'Phụ máy Cắt',
#   'Điều dưỡng trung cấp Nhân viên y tế học đường',
#   'Nhân Viên kỹ thuật',
#   'Công nhân sấy',
#   'Nhân Viên  kỹ sư xây dựng',
#   'Nhân viên vệ sinh đổ sợi',
#   'byv bình dương',
#   'Phó ban thời sự',
#   'Phụ gò',
#   'Công nhân xưởng cắt',
#   'Công nhân Phục vụ',
#   'Công nhân đánh số sản phẩm',
#   'Công Nhân Pha Keo',
#   'CN vận hành thiết bị',
#   'giáo viên trường THCS nguyễn huệ',
#   'Công nhân  May 55',
#   'Công nhân sản xuất Tôm',
#   'Công nhân đan',
#   'CN ra phôi',
#   'Lái xe trung chuyển Cần Thơ - Vùng 2',
#   'tổ trưởng nấu nhôm thau',
#   'Tổ Phó',
#   'Công nhân đổi kim',
#   'Công nhân là bậc 1/6',
#   'Cao đẳng Hộ sinh',
#   'P.Gíam đốc',
#   'Công nhân Cá cắt',
#   'nhân viên xuất hàng',
#   'Nhân viên bốc xếp thủ công ở các kho',
#   'Công nhân sửa chữa máy may',
#   'Nhân viên chăm sóc sắc đẹp',
#   'nvvv',
#   'CN cắt nhiệt',
#   'Lái xe 46 chỗ',
#   'công nhân vô lon cá',
#   'công nhân kiểm tra sản phẩm.',
#   'Công Nhân Sản Xuất Điện tử',
#   'Công nhân Phun sơn',
#   'Công Nhân Sơn Mài',
#   'Nhân viên vệ sinh bộ phận kéo dài',
#   'Nhân viên thu ngân',
#   'Nhân viên phục vụ ẩm thực',
#   'Kiến trúc sư  Thiết kế',
#   'Công nhân định vị',
#   'Nhân viên Văn thư',
#   'Thợ Hàn',
#   'Data Operator-Chuyên viên xử lý dữ liệu',
#   'Nhân Viên tổ Nền',
#   'Kiểm soát viên thuế',
#   'KIểM HàNG',
#   'Thợ may trong chuyền may',
#   'Kỹ thuật viên Đo đạc địa chính',
#   'Điều dưỡng hạng IV  Khoa Chẩn đoán hình ảnh  Bệnh viện ĐKKV Bắc Quảng Bình',
#   'Nhân viên giao dịch khách hàng',
#   'Công Nhân Vận Hành Máy may công nghiệp',
#   'Công nhân phụ tổ inox',
#   'Công nhân đứng máy dán - thủ dầu một - bình dương',
#   'Công nhân Chỉnh Lý',
#   'Công nhân trồng  chăm sóc cao su',
#   'lao động hợp đồng',
#   'trải vải',
#   'Công nhân chuyền dập  KCN Long Khánh  thành phố Long Khánh  tỉnh Đồng Nai',
#   'Nhân viên bán hàng tại cửa hàng xăng dầu',
#   'Giao dịch viên thẻ',
#   'Công nhân vệ sinh giày',
#   'CN thu tiền nước',
#   'Nhân viên - V04 - Tỉnh Sơn La',
#   'Nhân viên lái xe tải dưới 01 tấn',
#   'phục vụ bàn',
#   'Công nhân khoan nổ mìn khai thác đá',
#   'NV hành chánh',
#   'Kỹ thuật viên Dây máy',
#   'Vận hành máy gò giày',
#   'Tổ trưởng Bảo vệ',
#   'Công nhân sơn tay',
#   'X8-Lap rap',
#   'Công  Nhân Ván',
#   'Nhân viên nhà hàng',
#   'Trưởng phòng sản xuất',
#   'Nhân viên phục vụ bậc 1',
#   'Công nhân may máy',
#   'NV Phục Vụ quầy Bar',
#   '275744',
#   'Công nhân phụ  cắt giầy nữ',
#   'Giám sát KV',
#   'Nhân viên bán vé trên xe buýt',
#   'KTV Dây Máy',
#   'Chỉ huy phó CHQS xã',
#   'Giáo viên THPT',
#   'nhân viên bảo trì máy may',
#   'Công Nhân Chặt',
#   'Trợ Lý',
#   'Thợ phụ chuyền may công nghiệp',
#   'Nhân viên Khách Sạn',
#   'CN. Kiểm Hàng',
#   'Công nhân sản xuât',
#   'Chiến sĩ Đội bảo vệ chuyên ngành',
#   'Công Nhân Lắp Ráp 420',
#   'Công nhân Đứng máy ép đế',
#   'Công nhân Sản xuất linh kiện Điện tử',
#   'Nhân viên Làm việc tại Quảng Nam Vùng 2',
#   'Cán bộ văn phòng thống kê',
#   'Địa Chính -Xây Dựng',
#   'Phó Giám đốc Trung tâm Marketing  CSKH và Phát triển Thương hiệu SHB',
#   'Nhân viên Chi nhánh Văn phòng đăng ký đất đai huyện Mỏ Cày Bắc',
#   'Nhân viên kỹ thuật HĐLĐ',
#   'Ca Trưởng Dệt vi tính',
#   'Công nhân khai thác than hàm lò',
#   'NV Bán Hàng',
#   'Trưởng quầy Bar',
#   'Kế toán - Tổ trưởng HC',
#   'bọc gót',
#   'Giám Sát Công Trình',
#   'nhân viên hành chính',
#   'Y Sỹ',
#   'KS-3/8',
#   'Đông lạnh-Vùng 3',
#   'Công nhân kỹ thuật điện',
#   'Công nhân-đứng máy IP',
#   'Cán bộ ban tuyên giáo',
#   'NV giới thiệu và tư vấn sản phẩm Microsoft',
#   'nhân viên thống kê. 1.5  bậc 1/15',
#   'CN phun Sơn',
#   'Nhân viên Tư Vấn - V04 - Tỉnh Vĩnh Long',
#   'Chuyên viên kỹ thuật dự án modul hóa',
#   'Giáo viên Mầm non Bình Lư',
#   'Nhân viên Kho Bảo Hành Điện Máy Xanh',
#   'Nhân viên phòng thử  nghiệm',
#   'CB Tư pháp - hộ tịch',
#   'Công nhân gắn linh kiện',
#   'Công nhân chuyền men',
#   'chuyên viên-BHXH huyện Thạnh Hoá',
#   'Coõng nhaõn Eựp suaỏt thaứnh hỡnh caực saỷn phaồm cao su',
#   'Chủ Quản Bảo Trì',
#   'Công nhân thao tác',
#   'Công nhân Giầy mẫu',
#   'Công nhân sửa chữa cơ khí mỏ',
#   'nguyên liệu  đóng kiện trong dây chuyền dệt may',
#   'Công Nhân Quét Keo',
#   'Công nhân  hình ảnh',
#   'CN Xưởng may',
#   'Công nhân QA - OQC - R2',
#   'Chủ tịch hội LHPN xã',
#   'Nhân viên Tiếp Đón Khách Hàng - V03 - Tỉnh Bình Phước',
#   'Công nhân sơn',
#   'Nhân Viên Bán Hàng - Tp. Hà Nội - Kv1',
#   'Công nhân chuyền K.Harness',
#   'chăm sóc khách hàng',
#   'Công nhân may công nghiệp - LINE 12',
#   'Công nhân duy tu đường sắt',
#   'Công nhân kinh doanh - Điện lực TP Vinh',
#   'GV-TH LKA1',
#   'BếP ĂN',
#   'Công Nhân Phối Hàng',
#   'Nhân viên Bảo hành',
#   'Tổ Keo',
#   'Công nhân pha trộn cát làm khuôn đúc',
#   'Công nhân trãi vải',
#   'TỔ TRƯỞNG TỔ RÁP',
#   'Nhân viên kỹ thuật chăn nuôi',
#   'Nhân viên Tư Vấn - V01 -  Thanh Trì - TP. Hà Nội',
#   'Cộng Nhân Kiểm tra chất lượng - IP',
#   'Nhân viên phòng Logistics',
#   'Giáo viên Thể dục',
#   'Nhân viên y tế - văn thư',
#   'Nhân viên sửa đồ',
#   'Nhân viên khuôn',
#   'Giáo viên trường THCS Thạnh Hoà',
#   'công nhân-may công nghiệp',
#   'Công nhân phòng QUảN Lý SảN XUấT',
#   'KTV Mắc hồ ghép',
#   'C.n May',
#   'Công nhân ép keo  XN May ĐT',
#   'Công nhân ngồi máy lạng da',
#   'Thiết kế 3D',
#   'NV Tiếp thị',
#   'công nhân-HĐ 01 năm',
#   'Công nhân bộ phận bao gói',
#   'Lái xe hầm',
#   'Công nhân phòng QC',
#   'CN vệ sinh đội VSMT Số 01',
#   'CN SX các SP làm bằng nhựa Composite',
#   'Công Nhân Kỹ Thuật Đánh Bóng',
#   'QĐ khai thác mỏ sét - CN nhà máy gạch Vũ Oai',
#   'Công Nhân Thao Tác',
#   'Nhân Viên Bán Hàng - Thanh Hoá - Thành Phố Thanh Hóa - Kv3',
#   'Công nhân Cắt Chỉ',
#   'Chuyên viên Địa chính tài nguyên môi trường',
#   'Nhân viên Quan hệ khách hàng',
#   'thợ may cn',
#   'Công nhân pha phao nhỏ C',
#   'Công Nhân May công nghiệp',
#   'Công Nhân Cắt',
#   'Phay CNC',
#   'Thợ Sửa chữa',
#   'Đội trưởng thi công - Đội Thi công',
#   'CHT',
#   'Nhân viên sửa chữa điện',
#   'Ca Phó Thành Phẩm',
#   'Công nhân bồn bông',
#   'Nhân viên hỗ trợ đại lý',
#   'CN - UMDE9',
#   'Thợ bảo trì điện',
#   'Nhân viên QA',
#   'công nhân toà nhà l',
#   'lái xe hạng B1  B2',
#   'Nhân viên làm việc tại Hải Dương /vùng 2',
#   'Công nhân đóng gói linh kiện bàn kiếng',
#   'Nhân viên nghiệp vụ An Giang  Phòng Nghiệp Vụ ĐTP',
#   'Công nhân trang trí bề mặt gỗ  bậc 1/7',
#   'Kỹ thuật viên vận hành',
#   'Công nhân Hoàn Chỉnh',
#   'Công nhân Ra gỗ-B',
#   'Công nhân LDS',
#   'Nhân Viên Kinh Doanh Dự án Samsung',
#   'Công nhân Đứng Máy',
#   'NV vận hành',
#   'Kế toán BH - HCM',
#   'VHSX',
#   'Công nhân Nhuộm',
#   'Nhân viên - V03 - Tỉnh An Giang',
#   'Nhân  viên',
#   'Công nhân quản lý vận hành lưới điện trung  hạ thế - Điện lực Sông Mã',
#   'Công nhân sản xuất  Bộ phận sơn gia công',
#   'Công nhân tổ ép phun 2',
#   'BảO MẫU',
#   'Nhân viên Phòng kinh doanh',
#   'Thợ bánh mỳ',
#   'CN mắc sợi',
#   'bvệ',
#   'Thợ cắt',
#   'Phó Chủ Tịch Hội Liên Hiệp Phụ Nữ  Hội Liên Hiệp Phụ Nữ phường',
#   'Khâu ó ca 2',
#   'CÔNG NHÂN SƠN',
#   'Công nhân thủ kho',
#   'Công Nhân  may công nghiệp',
#   'công việc',
#   'Công Nhân Kiểm Tra Chất Lượng',
#   'NV Vận hành',
#   'NV dệt sợi',
#   'CN sơn  in da và pha chế hoá chất để sơn  in da',
#   'Nhân viên Bán hàng VinMart+',
#   'Công nhân là  gấp đóng gói sản phẩm may',
#   'Nhân viên Quận 1  HCM vùng 1',
#   'CN Tp HCM - V1 - NV Nhóm Chuyên doanh Sim số',
#   '004672 Công nhân',
#   'Giáo viên dạy TH  Lái xe  TT ĐT Lái xe ô tô Cơ giới',
#   'công nhân phục vụ phụ trợ',
#   'Cán sự -Phóng viên',
#   'Công nhân vẽ',
#   'Công nhân bộ phận Dập dao thìa dĩa inox',
#   'Văn phòng - Thống kê',
#   'Cán bộ văn hóa xã hội',
#   'Công nhân phụ máy bồi dán',
#   'Công nhân In Lụa',
#   'Công nhân chế biến muối',
#   'LáI xe tải',
#   'công chức văn hoá xã hội',
#   'Nhân Viên Bộ Phận Nos J',
#   'Nv Thống kê',
#   'BM',
#   'Công nhân Xi mạ',
#   'giáo viên trung học',
#   'Công nhân làm đường',
#   'Nhân Viên Báo Cáo Số Liệu',
#   'CÔNG NHÂN NHUỘM',
#   'Phụ việc tổ chỉnh',
#   'Phó Chủ Tịch UBND',
#   'NV. Sinh Quản  Khu CN Suối Tre  TX. Long Khánh  Đồng Nai',
#   'Phó trưởng Phòng Kinh doanh Tổng hợp - Điện lực Tương Dương',
#   'Công nhân Thời trang',
#   'Hợp đồng giáo viên mầm non',
#   'Công nhân xưởng may',
#   'Nhân viên - V04 - Tỉnh Lai Châu',
#   'NHÂN VIÊN VĂN PHÒNG',
#   'Nhân viên lái xe tải',
#   'cnsx',
#   'Nhân viên trợ giảng',
#   'Công nhân dập móc bin',
#   'Chủ Hộ Kinh Doanh',
#   'Kiểm hóa',
#   'Nhân viên nước cấp-nước thải',
#   'Giáo viên Trường TH Hồ Tùng Mậu',
#   'Công nhân thi công',
#   'Đại diện bán hàng',
#   'nhân viên tài xế',
#   'Công nhân Thao tác máy phun đúc',
#   'Bảo vệ nội bộ',
#   'TỔ TRƯỞNG',
#   'Công nhân sofa',
#   'Công nhân điện thêu',
#   'Công Nhân Tổ ĐàO TạO',
#   'Công Nhân Phòng Pha Màu',
#   'công nhân phân xưởng kiểm nghiệm',
#   'Lái máy xúc',
#   'CN xưởng gỗ',
#   'Công nhân sinh quản',
#   'Công nhân thao tác máy kéo',
#   'Nhân Viên bán Hàng',
#   'Nhân viên cung ứng',
#   'Nhân viên nguyên vật liệu Kho',
#   'Nhân viên maketing',
#   'Công nhân Dập tay 2/2',
#   'Tổ trưởng sản xuất',
#   'Khai thác phi thoại  giao dịch tiếp thị',
#   'Công nhân-GEA922',
#   'lái xe Taxi',
#   'điều dưỡng viên',
#   'Bếp',
#   'Lái máy xúc đào',
#   'Nhân viên bán hàng NGHE AN/vùng 2',
#   'Công Nhân Nấu ăn',
#   'Công nhân hoàn chỉnh 3',
#   'công nhân đứng máy lấy hàng',
#   'Công nhân Tổ công vụ',
#   'Giám sát viên bảo vệ',
#   'Nhân viên kiểm tra chất lượng phòng Lab',
#   'TD 14/08/2012',
#   'Công nhân  QC',
#   'công nhân ván ép',
#   'Công nhân đứng máy vạn mã lực',
#   'Nhân viên Bảo Trì',
#   'CN Đóng Gói',
#   'Nữ hộ sinh  trưởng trạm y tế xã đông hưng B',
#   '59119- NV Sales DSMs - Cần Thơ - Vùng 02',
#   'Phó BCH quân sự',
#   'Kỹ sư công nghệ kỹ thuật cơ khí 1/8',
#   'Nhân viên kho phụ liệu',
#   'Nhân viên Lobby Bar',
#   'Nhân Viên Học Vụ',
#   'TKT',
#   'Công nhân ép đế B',
#   'Phết Keo Đế Và Mũ Giầy',
#   'Công nhân sửa chữa thiết bị công trường khai thác bậc 6/7',
#   'Công nhân cắt vải trong công nghệ may',
#   'Cn May Công Nghiệp',
#   'Công nhân vận hành bơm nước',
#   'Công nhân nghiền bột giấy bậc 4/7',
#   'Kỹ sư điện - phó tổng giám đốc',
#   'Giáo viên - TH số 1 Nậm Xây',
#   'Công nhân tổ may',
#   'công nhân chặt tập chung',
#   'hiệu trưởng',
#   'Công nhân ép MEX bậc 1/6',
#   'Thống Kê',
#   'công nhân sợi',
#   'công nhân phụ kho',
#   'Công nhân trực tiếp sản xuất  làm việc theo chế độ 3 ca',
#   'CN phụ việc',
#   'Công nhân sản xuất đồ dùng bằng da bậc 1/6 N2A2.2',
#   'CÔNG NHÂN CÔNG NHÂN QIP',
#   'Nhân viên công vụ',
#   'Nhân viên HC - kế toán',
#   'Công NhânOrA3-Job',
#   'nhân viên Tạp vụ',
#   'CN lưới không gút',
#   'Công nhân lắp ráp  vận chuyển linh kiện  kiểm tra và đóng gói sản phẩm.',
#   'Nhân viên điều hành tuor kiêm thủ quỹ',
#   'cn đóng kiện trong dây chuyền may',
#   'Công Nhân Đổ PU',
#   'Kỹ thuật viên  Kinh Doanh',
#   'Công nhân sản xuất lắp ráp',
#   'công nhân quản lý đường dây và trạm chi nhánh điện tiên phước',
#   'cán bộ văn phòng',
#   'Công nhân là  bộ phận chuyền may',
#   'CÔNG NHÂN VẬN HÀNH MÁY MAY',
#   'CN Kéo khô',
#   'Thợ điện TĐH',
#   'Công nhân vận hành máy dệt khí',
#   'Công nhân vận hành máy bơm công suất>8000m3',
#   'Nhân viên khai thác hàng hóa nội địa',
#   'Công nhân LĐPT quét rác đường phố- bậc 1/7 - hệ số 1 31',
#   'Thợ đồng',
#   'ủi',
#   'C.nhân phụ may',
#   'Phường đội trưởng',
#   'CN là  gấp  đóng gói (may công nghiệp)',
#   'CN Đột dập',
#   'NV. Bảo vệ',
#   'Nhân viên Sơn Lót 2',
#   'Công nhân vận hành máy nghiền tuyển quặng sắt   CN',
#   'Công nhân Mài bụi đế lớn',
#   'Kỹ thuật viên chẩn đoán hình ảnh',
#   'Điều Hành',
#   'Nhân viên Tài xế',
#   'Giám sát nội thất',
#   'Nhân viên pha trộn sơn trong sản xuất ô tô  xe máy.',
#   'Nhân viên Giải đáp khách hàng',
#   'Nhân viên - V02 - Tỉnh Tiền Giang',
#   'Thợ hàn cắt b2',
#   'Công nhân phân xưởng Dỡ - Phân loại sản phẩm',
#   'Nhân viên thay thô sợi con',
#   'Nữ hộ sinh Trung học',
#   'Vận Hành Máy Ep A1',
#   'Công nhân lái xe tải đội xe từ 7.5 tấn đến 16.5 tấn',
#   'công nhân khuy nút',
#   'Công nhân tổ chuyền ngoài',
#   'Công nhân- Sắp xếp khuôn',
#   'CN cắt phá  cắt gọt',
#   'Gác ghi',
#   'Nhân viên bậc 2/12',
#   'chuyên viên - BHXH Mai Sơn',
#   'công nhân -  xưởng may',
#   'Công nhân tổ Ráp giày thành phẩm',
#   'Nhân viên làm việc tại An Giang',
#   'Công nhân - Phôi 3',
#   'Công Nhân May Thêu',
#   'NV Giao nhận-43/5 Lê Đại Hành  P Phước Mỹ  Phan Rang Tháp Chàm Ninh Thuận',
#   'Công nhân xếp bao',
#   'nhân viên lái xe',
#   'Công nhân trải vải  vận hành máy cắt vải',
#   'Công nhân tổ BTP',
#   'Cán bộ văn phòng',
#   'Công nhân sản xuất xà phòng bột  xà phòng kem',
#   'Thư ký toà án',
#   'Công nhân kho hàng',
#   'Công nhân khuôn đúc - A247237',
#   'Nhân viên bộ phận khuôn',
#   'Diễn viên Múa',
#   'công nhân sản xuất cần câu cá',
#   'Công nhân Lái xe',
#   'Nhân viên sửa bản in',
#   'Nhân viên bán hàng cao cấp',
#   'Giáo viên tiểu học chính bậc 1/10  Trường PTCS Vĩnh Phong thuộc',
#   'Chuyên viên nghiệp vụ depot',
#   'Công nhân chiếu xạ đế trung',
#   'Nữ hộ sinh trung học',
#   'Khâu cán ca 1-1',
#   'trung cấp xây dựng',
#   'Nhân viên hành chánh',
#   'Công nhân-dán da cố',
#   'P. Hiệu trưởng',
#   'Kế toán cửa hàng',
#   'LĐ phụ',
#   'Lắp ráp  vận chuyển linh kiện  kiểm tra và đóng gói sản phẩm',
#   'Nhân viên xưởng se sợi',
#   'Công Nhân Đùn Sợi',
#   'Điều dưỡng khoa Nội - Nhi - Nhiễm',
#   'Trải vải biên chính',
#   'giao dịch viên',
#   'Công nhân Sản xuất lắp ráp Tủ lạnh',
#   'Nhân viên Tiếp thị qua điện thoại',
#   'P.GĐốc',
#   'Công Nhân AL2-S1',
#   'CNQLVH Đường Dây & Trạm CNĐ Lục Ngạn',
#   'Nhân viên-Mercedes Benz VN',
#   'Công nhân Phòng chuẩn bị 2',
#   'GIáo viên - tổ phó',
#   'NVPV nhà ăn trường học',
#   'Tổ trưởng KSC',
#   'Công Nhân Vận Hảnh Máy May|(MCN)',
#   'Nhân viên Marketting',
#   'Thanh toán viên thanh',
#   'Công nhân may bậc 1/12',
#   'Công nhân VH thiết bị',
#   'N.v',
#   'Phân tích viên',
#   'Công nhân sản xuất linh kện điện tử',
#   'Văn phòng đảng ủy',
#   'lái xe cẩu',
#   'Công nhân sản xuất sản phẩm sơn mạ',
#   'Công nhân khai thác mỏ',
#   'Nhân Viên Bán Hàng - Yên Bái Kv4',
#   'Công nhân nghiền đá',
#   'Công nhân sơn in da và pha chế hóa chất để sơn  in da',
#   'CN t? in xoa',
#   'Công nhân vận hành máy gia công kim loại',
#   'ép Cao Tần',
#   'CN Bảo trì',
#   'công nhân (bp eva)',
#   'Công Nhân ủi Công Nghiệp',
#   'Nhân viên Kiểm phẩm kiêm thu mua lúa gạo',
#   'Nhân viên Lắp đặt',
#   'công nhân học việc',
#   'Quản lý -V01 - TP. Hồ Chí Minh',
#   'nhân viên tư vấn kinh doanh',
#   'Nhân viên đóng bao thành phẩm',
#   'Công nhân phân xưởng gia công',
#   'Phụ Bán Hàng',
#   'Nhân viên Phòng Chế tạo động cơ',
#   'Thợ cưa kim loại',
#   'Tổ trưởng nhà hàng',
#   'NV Hỗ trợ kỹ thuật tại nhà KH',
#   'NHóM TRƯởNG',
#   'lái xe trộn dưới 15 tấn',
#   'Nhân viên khai báo hải quan',
#   'NV.Phụ Xe',
#   'Giáo viên tiểu học',
#   'Nhân Viên Sinh Quản',
#   'CN Lựa Gỗ',
#   'Công nhân vô gòn 2',
#   'tổ phó',
#   'Công Nhân SX thiết bị y tế',
#   'Kỹ thuật viên Phân tích lỗi và sửa sản phẩm',
#   'Nhân viên phân liều',
#   'Nhân viên Thu ngân',
#   'Vận hành trạm điện 35 KV',
#   'Tổ Viên',
#   'Xã đội',
#   'Nhân viên hành chính - Làm việc tại TP.HCM (vùng 1)',
#   'Nhân viên - Hà Nội',
#   'dược sỹ trung học',
#   'Quản Lý Khâu may',
#   'Cửa hàng Phó -  Vùng 1-Hồ Chí Minh',
#   'nhân viên kỹ thuật chế tạo',
#   'Tư pháp hộ tịch - MS 01.004 bậc 1/12',
#   'Phó Chủ tịch Hội Phụ nữ',
#   'Nhân viên kỹ thuật - cơ khí - điện',
#   'công nhân tinh chế sản phẩm',
#   'Nhân viên - V04 - Tỉnh Ninh Thuận',
#   'Nhân viên điểm giới thiệu dịch vụ (Điện máy) - Nơi làm việc: Bình Dương',
#   'Công nhân khuôn đúc - A249231',
#   'NV Bốc xếp',
#   'Công nhân pha phao',
#   'Công nhân vận hành máy may - Line 38',
#   'Công Nhân ĐúC Đế(KP)',
#   'nhân viên bán xăng',
#   'ui',
#   'Công nhân chiếu xạ',
#   'Công Nhân Xưởng may',
#   'Công nhân sản xuất nhựa',
#   'Phó Bí thư',
#   'Đội Viên Cảnh Vệ',
#   'Nhân viên Bảo vệ   Lái xe',
#   'Công Nhân May Trụ 1 Kim',
#   'Công nhân _ Thủ công',
#   'CN.Bảo Trì điện',
#   'Nhân viên sữa chữa  bảo dưỡng hệ thống lạnh  kho lạnh',
#   'Nhân viên đứng máy ghép',
#   '21996CÔNG NHÂN',
#   'Công nhân dệt sợi',
#   'Nhân viên lái xe xúc đường',
#   'Nhân viên - V02 - Tỉnh Bình Phước',
#   'Công nhân đứng máy chạy màng phủ',
#   'Công nhân tổ dệt',
#   'Sơn thủ công',
#   'văn hóa - xã hội',
#   'Nhân viên thủ quỷ',
#   'Trợ lý Quản lý khách hàng',
#   'công nhân phòng mẫu',
#   'Công nhân giặt',
#   'Nhân Viên Bán Hàng-Hcmc 1',
#   'Kiểm gấp trong dây chuyền may',
#   'Kỹ thuật viên Spa',
#   'CÔNG NHÂN DẬP',
#   '15087',
#   'NV nghiệp vụ',
#   'GDV chi nhà',
#   'Kho vận',
#   'Công nhân Chăm sóc',
#   'Công nhân vận Hành máy may công nghiệp',
#   'Chuyên Viên Bậc 1/8',
#   'Nhân viên Hỗ trợ kỹ thuật',
#   'NV PTTT',
#   'Công nhân bóc vỏ lụa',
#   'Công nhân vận hành Nhà máy Thủy điện Ea Krông Run',
#   'CN sản xuất điện tử',
#   'Phó Ban Điều hành',
#   'Lái xe con',
#   'KTV Xét nghiệm- khoa xét nghiệm',
#   'Công nhân QC dệt',
#   'dược sĩ',
#   'Nhân Viên Thu Ngân',
#   'Nhân viên - V03 - Nghệ An',
#   'kiểm phẩm',
#   'Nhân viên phòng kĩ thuật',
#   'Nhân viên dịch vụ khách hàng',
#   'Công nhân chế biến thủy hải sản đông lạnh- bộ phận dịch vụ cắt tiết',
#   'Công nhân trồng lúa',
#   'Công nhân lái xe tải P>= 7.5 tấn',
#   'Cán bộ VP - TK',
#   'KTV Thí nghiệm TS',
#   'Công nhân thợ may yếu',
#   'Công nhân kỹ thuật đóng gói',
#   'Công Nhân Đi Ca',
#   'công nhân in offset',
#   'Công nhân  thủ công',
#   'Địa chính xây dựng',
#   'Nhân viên thực nghiệm',
#   'Công nhân Xưởng In',
#   'N.V',
#   'Phiên dịch',
#   'Công nhân Kiểm hàng',
#   'Công Nhân Qc1',
#   'Kỹ thuật viên chính',
#   'Công nhân trộn liệu',
#   'công nhân sản xuất bê tông',
#   'Công nhân lộn găng',
#   'Công nhân Đứng Máy Chặt',
#   'Nhân viên kỹ thuật  Phòng Kỹ thuật - Quản lý Môi trường',
#   'Bán Hàng',
#   'tiếp viên hk',
#   'Cử nhn điều dưỡng',
#   'Nhân viên lái xe buÝt',
#   'Nhân viên - V04 - Tỉnh Bình Định',
#   'khai thác mủ',
#   'Công nhân đánh đầu',
#   'Công nhân gò',
#   'CN Kho',
#   'Công Nhân Phân Xưởng Hoàn Chỉnh',
#   'Nhân viên Buồng',
#   'Công nhân may Công Nghiệp',
#   'cn thủ công',
#   'Công nhân bộ phận NOS F',
#   'Nhân viên bán vé xe buÝt',
#   'CN PHụ',
#   'Nhân viên nhà ăn',
#   'cơ khí sửa chữa',
#   'Công nhân sản xuất linh kiện điện thoại',
#   'nhân viên bán hàng - Takashimaya',
#   'Công nhân bán lẻ xăng dầu  CHXD Hoàng Đông- Hoàng Đông  Duy Tiên  Hà Nam',
#   'nhân viên tín dụng',
#   'Công Nhân sản xuất Điện tử',
#   'Công nhân bộ phận kiểm hàng',
#   'Thợ mộc',
#   'nhân viên kế toán',
#   'Công nhân thủ công-Phân xưởng Long Xuyên',
#   'công nhân hoàn tất',
#   'Nhân viên Kế hoạch',
#   'Công nhân xưởng cá',
#   'Công nhân Xếp gỗ Tổ Kho gỗ',
#   'NV theo dõi bán hàng',
#   'cn ủi',
#   'công nhân Lái xe',
#   'Công Nhân Chuyền Kashito hita',
#   'Cán bộ dân số - Kế hoạch hoá gia đình Trạm y tế xã An Thành',
#   'Nhân viên lái xe taxi 04 chỗ',
#   'Tổ trưởng Nhóm Thành Phẩm',
#   'Giáo viên Tiểu học hạng  II',
#   'Thủ quĩ',
#   'Nhân viên phục vụ ăn uống',
#   'Công Nhân Dán Flywire No-Sew',
#   'CN Dệt',
#   'Công nhân là vải may công nghiệp',
#   'Nhân viên CND Thanh Sơn',
#   'Trưởng ca thu phí',
#   'công nhân xỏ dây',
#   'Công nhân xưởng Tráng vải bạt',
#   'Nhân viên Kĩ thuật',
#   'Nhân viên bán hàng Chi nhánh Tiền Giang',
#   'KIỂM PHẨM',
#   'CNSX chuyền Ferrule',
#   'Nhân viên ép vỉ',
#   'Nhân viên pha chế',
#   'nhân viên vệ sinh công cộng',
#   'Phụ Xe',
#   'Nhân viên quản lý bảo trì',
#   'VM+ Nhân viên Bán hàng - Vùng 2 - Nha Trang',
#   'Công Nhân Bó Buộc',
#   'Công nhân vá lưới',
#   'Nhân viên Kho Điện Máy - V03 - Châu Thành A - Hậu Giang',
#   'NV phụ xe',
#   'NV Thị trường',
#   'Ó 1-4',
#   'Công Nhân chuyền Học Tủ',
#   'Nhân viên Bếp Hoa',
#   'Nhân Viên ThườNg - Bộ Phận Kinh Doanh Khu Vực Đông Bắc 1',
#   'Công Nhân Vệ sinh',
#   'Nhân viên phụ trách công tác môi trường',
#   'Nhân viên kiểm bao đánh ống',
#   'Công nhân Gắn nhiệt',
#   'Thợ máy - 3/7',
#   'Nhân viên Tiếp đón Khách Hàng',
#   'Công nhân bán lẻ xăng dầu  CHXD số 5',
#   'Công nhân may Mẫu  XN may ĐT',
#   'Nhõn viờn kiểm hàng',
#   'Công nhân thêu',
#   'nhân viên vận hành trạm cấp nước',
#   'NV Kỷ thuật',
#   'công nhân SƠN',
#   'Công nhân in caochupo',
#   'Thợ mài trụ',
#   'Phụ trách Điều Hành_CNVT',
#   'công nhân ống',
#   'Nhân viên điểm giới thiệu dịch vụ (Xe máy) - Nơi làm việc: Bắc Giang',
#   'Nhân viên - V02 - Tỉnh Hải Dương',
#   'Công nhân Thủ Công',
#   'CN mài quần bò',
#   'Thợ May',
#   'CN TMIL B2',
#   'CN Vòi Nước',
#   'Công nhân thành hình  KCN Long Khánh  thị xã Long Khánh  tỉnh Đồng Nai',
#   'công nhân phụ may công nghiệp',
#   'kho',
#   'NV PV Nhà hàng',
#   'Công nhân vận hành dây chuyền kéo sợi',
#   'Tổ phó - Giáo viên',
#   'Quản lÝ',
#   'Công nhân: Hàn điện  hàn hơi',
#   'Nv. Bán Hàng',
#   'Nhân viên thợ quầy thịt',
#   'Công nhân cưa xẻ gỗ',
#   'Công nhân Mihonchou',
#   'Công nhân Chế biến thủy  hải sản đông lạnh',
#   'Nhân Viên Bảo Trì',
#   'Nhân viên Bếp chính',
#   'Công nhân khai thác mủ cao su - Nông trường cao su Ia Chim',
#   'Điều dưỡng TC',
#   'Công Nhân Roll - Outside',
#   'Công nhân Lò sấy',
#   'Công nhân Xưởng gia công',
#   'Nhân viên thị trường',
#   'Bán vé',
#   'Phó Phòng HC NS',
#   'Y sĩ y học cổ truyền',
#   'đd tc',
#   'Giám đốc phòng giao dịch Agribank chi nhánh huyện Hưng Nguyên',
#   'lái xe nâng',
#   'Công Nhân ép',
#   'Đầu bếp bếp á bếp trên 100 xuất',
#   'Công nhân vận hành XN sản xuất KD nước sạch Bảo Thắng',
#   'công nhân - Bảo trì (2010)',
#   'Công Nhân - Worker',
#   'Công nhân Upper',
#   'Phó trưởng khoa',
#   '915031-c',
#   'Lái xe vận tải - có trọng tải từ 7 tấn đến dưới 20 tấn',
#   'Giám sát buồng phòng',
#   'Đại học tiếng anh',
#   'CB Kỹ thuật TKBT',
#   'Nhân viên - V04 - Tỉnh Đắk Nông',
#   'Nhân viên Dịch vụ sau bán hàng - V01 - Q.Thủ Đức - Hồ Chí Minh',
#   'nhân viên-101',
#   'chuyền trưởng',
#   'Vận hành lò hơi',
#   'CN VH Dây chuyền sợi',
#   'Nữ Hộ sinh',
#   'Công nhân lắp dựng',
#   'Công Nhân Sản Xuất gỗ',
#   'CB.Kiểm kê',
#   'Công nhân - Bộ phận Sản xuất',
#   'Công nhân bảo trì',
#   'NV Lái xe',
#   'Công Nhân Cao Tốc',
#   'Phụ bếp',
#   'Nhân viên sửa chữa - bảo trì máy may công nghiệp',
#   'Nhân viên đóng gói',
#   'Công nhân quản lý và khai thác đèn biển trên các đảo và cửa biển',
#   'Nhân viên Dịch vụ khách hàng - Thu ngân',
#   'Nhân viên  Kỹ thuật',
#   'Thư ký',
#   'Nhân viên - V03 - Tỉnh Cao Bằng',
#   'Tư Pháp - Hộ Tịch (MN:01.004)',
#   'CN Hà Nội - V1 - NV Nhóm Chuyên doanh Laptop',
#   'Nhân viên thị trường  Phòng kinh doanh',
#   'Công nhân Lăn trở bánh phồng tôm',
#   'Công Nhân ĐẠI ĐẾ(ÉP ĐẾ-A)',
#   'Điều Dưỡng',
#   'Điều dưỡng trung cấp',
#   'Kỹ sư tập sự bậc 1/9',
#   'Công nhân Đắp vá',
#   'công nhân bao gói 2',
#   'Điều phối giao nhận',
#   'CN lái máy',
#   'Công nhân- kỹ thuật',
#   'thợ hàn',
#   'Tổ chức',
#   'Trợ lý QC',
#   'Nhân viên quầy rau quả',
#   'Lái máy xúc lật',
#   'Chuyên viên  Phòng Cấp sổ thẻ',
#   'Phó phòng KHKT-VT',
#   'Thợ gá',
#   'Công nhân thay thân',
#   'Công nhân trực tiếp sản xuất',
#   'Công Nhân Đùn Sợi',
#   'Công nhân dán lốp',
#   'cn gạch',
#   'công nhân cơ khí',
#   'Gíao viên trường tiểu học  tân phước 1',
#   'Nhân viên Trang Trí kiêm Thu ngân - Sim Số - V01 - Thủ Dầu Một - Bình Dương',
#   'Nhân viên bán hàng tại Lào Cai- Vùng 2',
#   'Phó quản đốc',
#   'Nhân viên hiện trường Dịch vụ hải quan',
#   'công nhân ép mex (may công nghiệp)',
#   'Chủ tịch Hội liên hiệp phụ nữ',
#   'công nhân băng chuyền',
#   'CN nề',
#   'Kỹ sư kỹ thuật xây dựng',
#   'Nhân viên thiết bị tin học',
#   'công nhân  Hoàn Chỉnh',
#   'Nhân viên Bảo vệ chuỗi',
#   'An toàn viên',
#   'Nhân Viên Điều Tra - Miền Nam',
#   'Công nhân Điện',
#   'Thu thuê bao CN Hậu Giang',
#   'Trưởng phòng An toàn Lao động',
#   'Công nhân kỹ thuật may',
#   'Nhân viên thư viện',
#   'Vh Máy Xay  Nghiền',
#   'Công nhân sản xuất phân bón',
#   'GV Trường MG Nậm Mòn',
#   'Công nhân Tổ Tinh 5',
#   'Chuyên viên Địa chính- xây dựng',
#   'Nhân viên phòng Chất lượng',
#   'Nhân viên sản xuất Phòng gia công',
#   'Công nhân vận chuyển vải may CN',
#   'MCS/Nhân viên',
#   'Nhân Viên Bán Hàng Qua Điện Thoại',
#   'CĐ Công nghệ ô tô',
#   'KTV Sắt hàn. XN Cơ khí ô tô Chuyên dùng An Lạc. 36 Kinh Dương Vương  P.An Lạc A  Q.Bình Tân  TP.HCM.',
#   'Nhân viên quản lý vận hành trạm',
#   'Công nhân Phụ May -4005',
#   'Trưởng phòng Thương mại',
#   'Nhân viên Bốc Xếp',
#   'NV KTVT',
#   'kiểm hàng',
#   'Công nhân chi nhánh Phú Quốc',
#   'Nhân viên Thu Ngân - Sim Số - V02 - T. Quảng Ninh',
#   'Công nhân mài ngồi',
#   'Trưởng nhóm Hỗ trơ thị trường miền Nam',
#   'Công  nhân quét rác đường phố',
#   'Giám đốc Quan hệ khách hàng - RB (phi tín dụng) TP CAO LÃNH - ĐỒNG THÁP',
#   'Hành chánh',
#   'CN CắT BIÊN',
#   '2253',
#   'công nhân hàng trắng cắt',
#   'công nhân chế biến thủy sản',
#   'Công Nhân Giặt Tẩy',
#   'May công nghiệp (Công nhân cắt phá  cắt gọt)',
#   'Công nhân phòng khuôn',
#   'Công nhân sản xuất dây điện',
#   'Chủ tịch hội phụ nữ',
#   'Công nhân cát bavia',
#   'đội  trưởng thi công',
#   'Cn vận hành máy may công nghiệp',
#   'Điều dưỡng trung học Khoa Phẫu Thuật Gây Mê Hồi Sức',
#   'Nhân viên Dịch vụ sau bán hàng - V03 - Vị Thanh - Hậu Giang',
#   'Nhân viên bán hàng Quầy Viễn thông 35',
#   'Công nhân Pha keo',
#   'Phó Hiệu Trưởng',
#   'Nhân Viên Bán Hàng - Điện Biên - Kv4',
#   'Lái xe ô tô tải hạng FC',
#   'công nhân mài',
#   'Công nhân bộ phận bao gói mỳ',
#   'Công nhân Ráp 1',
#   'Công nhân - Lắp ráp 2',
#   'Nhân Viên Kcs Thành Phẩm',
#   'CN TT trồng rừng và khai thác gỗ',
#   'DTP: Giao hàng -Thu Tiền',
#   'Dân số',
#   'Nhân viên sản xuất Module',
#   'Cơng nhn bộ phận May Long Thnh',
#   'Công nhân là hơi',
#   'Nhân viên hoá chất',
#   'Cán bộ Dân Số KHHGĐ-',
#   'Cán bộ  Văn phòng thống kê',
#   'CÔNG NHÂN LẮP RẮP ĐIỆN TỬ',
#   'công nhân khai thác mủ cao su',
#   'CÔNG NHÂN SẢN XUẤT',
#   'Công nhân  KTCL Chip 2',
#   ...},
#  1569)
